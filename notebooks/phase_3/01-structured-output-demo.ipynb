# %%
import openai
import instructor
from pydantic import BaseModel, Field
from qdrant_client import QdrantClient

# %% [markdown]
# ### Mock Example

# %%
prompt = """
 You are a helpful assistant. 
 Return an answer to the question. 
 Question: What is you name? 
"""

# %%
response = openai.chat.completions.create(
 model="gpt-4.1-mini",
 messages=[
    { "role":"system", "content":"prompt"}
 ]
)
print(response.choices[0].message.content)
# Out:
# Hello! How can I assist you today?

# %% [markdown]
# ### Add instructor (structured outputs)

# %%
client = instructor.from_openai(openai.OpenAI())

# %%
class RAGGenerationResponse(BaseModel):
    answer:str = Field(description="Answer to the question.")

# %%
response, raw_response = client.chat.completions.create_with_completion(
 model="gpt-4.1-mini",
 messages=[
    { "role":"system", "content":"prompt"}
 ],
 response_model=RAGGenerationResponse
)
# print(response.choices[0].message.content)

# %%
response.model_dump()
# Out:
# {'answer': 'Based on the provided prompt, the user has requested you to think step-by-step and carefully analyze the problem, and then solve it. However, they have not actually stated a specific problem or question to solve. To assist you efficiently, please provide the problem or question you want me to solve.'}

# %%
raw_response
# Out:
# ChatCompletion(id='chatcmpl-CUpEpPR4yXLn6uzrE1nkldFu1ve11', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_1vunRNnBNilY4zqkcBhJycvH', function=Function(arguments='{"answer":"Based on the provided prompt, the user has requested you to think step-by-step and carefully analyze the problem, and then solve it. However, they have not actually stated a specific problem or question to solve. To assist you efficiently, please provide the problem or question you want me to solve."}', name='RAGGenerationResponse'), type='function')]))], created=1761462835, model='gpt-4.1-mini-2025-04-14', object='chat.completion', service_tier='default', system_fingerprint='fp_4c2851f862', usage=CompletionUsage(completion_tokens=63, prompt_tokens=75, total_tokens=138, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %% [markdown]
# ### RAG Example

# %%
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=text,
        model=model,
    )

    return response.data[0].embedding


def retrieve_data(query, qdrant_client, k=5):

    query_embedding = get_embedding(query)

    results = qdrant_client.query_points(
        collection_name="Amazon-items-collection-00",
        query=query_embedding,
        limit=k,
    )

    retrieved_context_ids = []
    retrieved_context = []
    retrieved_context_ratings = []
    similarity_scores = []

    for result in results.points:
        retrieved_context_ids.append(result.payload["parent_asin"])
        retrieved_context.append(result.payload["description"])
        retrieved_context_ratings.append(result.payload["average_rating"])
        similarity_scores.append(result.score)

    return {
        "retrieved_context_ids": retrieved_context_ids,
        "retrieved_context": retrieved_context,
        "retrieved_context_ratings": retrieved_context_ratings,
        "similarity_scores": similarity_scores,
    }


def process_context(context):

    formatted_context = ""

    for id, chunk, rating in zip(context["retrieved_context_ids"], context["retrieved_context"],context["retrieved_context_ratings"]):
        formatted_context += f"- {id}:, rating:{rating}, description:{chunk}\n"
      

    return formatted_context


def build_prompt(preprocessed_context, question):

    prompt = f"""
You are a shopping assistant that can answer questions about the products in stock.

You will be given a question and a list of context.

Instructtions:
- You need to answer the question based on the provided context only.
- Never use word context and refer to it as the available products.

Context:
{preprocessed_context}

Question:
{question}
"""

    return prompt

def generate_answer(prompt):
    client = instructor.from_openai(openai.OpenAI())

    response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        messages=[{"role": "system", "content": prompt}],
        temperature=0.5,
        response_model=RAGGenerationResponse
    )

    return response


def rag_pipeline(question, qdrant_client, top_k=5):

    retrieved_context = retrieve_data(question, qdrant_client, top_k)
    preprocessed_context = process_context(retrieved_context)
    prompt = build_prompt(preprocessed_context, question)
    answer = generate_answer(prompt)

    final_result = {
        "answer": answer.answer,
        "question": question,
        "retrieved_context_ids": retrieved_context["retrieved_context_ids"],
        "retrieved_context": retrieved_context["retrieved_context"],
        "similarity_scores": retrieved_context["similarity_scores"]
    }

    return final_result

# %%
qdrant_client = QdrantClient(url="http://localhost:6333")

# %%
output = rag_pipeline("Can I get a tablet",qdrant_client)

# %%
output
# Out:
# {'answer': 'Yes, you can get a tablet. There are several tablets available including:\n- DUODUOGO 2 in 1 Tablet 10 Inch with Keyboard Mouse Stylus, 128GB Expandable, 64GB ROM, 4GB RAM, Android 10.0, Quad-Core HD IPS Screen\n- DOOGEE T10 Android Tablet 2023, 10.1" FHD+ Android 12 Tablet, 15GB RAM + 128GB Storage, Octa-Core, 8300mAh Battery\nThese tablets offer various features suitable for study, entertainment, gaming, and video conferencing.',
#  'question': 'Can I get a tablet',
#  'retrieved_context_ids': ['B0B44TGKRX',
#   'B0C35RS6MS',
#   'B0BK8458S2',
#   'B0B23RZWTH',
#   'B0C2C7NMGP'],
#  'retrieved_context': ['DUODUOGO 2 in 1 Tablet 10 Inch with Keyboard Mouse Stylus, 128GB Expand 64GB ROM 4GB RAM Android 10.0 Quad-Core HD IPS Screen 8MP Dual Camera GPS FM OTG Bluetooth 4G Dual SIM & WiFi, DGO-P610.1 Inch HD IPS Tablet - This tablet features a 1280*800 HD G+G IPS touch display, wide viewing angle, bright display, more vivid colors and top-notch picture quality. High Performance 2 in 1 Tablet - Equipped with 4GB RAM, 64GB ROM, you can expand the storage up to 128GB using a Micro SD card (not included). Perfect for daily study and entertainment use. Android 10.0 Tablet - An Android 10.0 tablet can watch videos like YouTube and Netflix. Use ZOOM, Skype, etc. to join the meeting. Also chat with friends on Facebook, WhatsApp. LONG BATTERY LIFE - 8000mAh built-in rechargeable battery and low-power CPU enhance your experience, with long runtime and standby time, you can enjoy up to 8 hours. PERFECT GIFT - The DUODUOGO P8 tablet is suitable for all ages, seniors can use it to watch TV, kids can use it to play games and study, office workers can use it to participate in video conferences. It is the best choice for gift giving!',
#   'DOOGEE T10 Android Tablet 2023, 10.1" FHD+ Android 12 Tablet, 15GB+128GB Octa-Core Gaming Tablet, 8300mAh Battery 2.4G/5G WiFi Tablet, TÜV Low Bluelight Tablet Android, Bluetooth, GPS, Split Screen【Larger Storage & Lightweight】Android tablet is equipped with 15GB RAM and 128GB storage, up to 1TB micro SD card for expandable storage. You don\'t need to worry about no space to keep your data, photos, games, music, videos, eBook, etc. Huge storage also ensures a fast running speed. 【TUV certification】Are you still worried about the damage of blue light to your eyes? DOOGEE android tablet have Hardware level filter blue light technology and passed the TUV blue light eye protection certification that can reduce the damage to blue light to the eyes by 58%.This android tablet protects your eyes watching TV, watching videos, and playing games. 【High-performance processor】Doogee android tablet is different from other android 12 tablet of the same price. It is equipped with the most cost-effective Spectrum T606 Octa-Core processor in 2022 and delivers processing power up to 1.6 GHz. You can play your favorite games, watch 4k live-streaming, have online meetings and lessons, and have a smooth multitasking experience. 【Dual Speakers】Android 12 tablet uses a 10.1-inch 1920X1200 resolution FHD IPS display provided by BOE technology, 16:10 screen ratio view angle, paired with 300 nits brightness, and T-Color 2.0 color optimization technology, that can present vibrant and colorful picture quality. Momentum III system with Dual speakers delivers clearer and louder audio, making you enjoy an immersive sound experience. 【 Wide vine DRM at L1】Doogee android tablet has another welfare. It is certified by Google\'s Wide vine DRM at L1 that can download encrypted apps and watch the encrypted video, such as Netflix and Amazon Prime Video. 【Excellent After-sales Service】 DOOGEE android tablet enjoy a two-year warranty service after the purchase, and welcome to share your excellent experience. If you have any problems, Plz contact us in time, and we will try our best to solve your problem. CONTACT US: Login your amazon account > choose "Your orders" > find the order > click "Contact seller".',
#   'JETech Case for iPad 9.7-Inch (6th/5th Generation, 2018/2017 Model) with Built-in Screen Protector, Protective Shockproof Rugged Tablet Cover, 360° Rotating Hand Strap Stand (Navy)[Compatibility] Designed for iPad 9.7-Inch (6th/5th Generation, 2018/2017). Fit models: A1893 A1954 A1822 A1823 . Please check the back bottom of your iPad to find the model number [Heavy Duty Protection] 3-Layer total front and back case for full protection. A PC front cover with built-in PET screen protector, hard PC inner shell and flexible TPU back shell. Perfectly protect your device against unexpected drops, scratches and shocks [360° Rotating Kickstand & Hand Strap] Easily support your iPad in multiple angles. Moreover, the soft hand strap allows you to hold your iPad firmly and comfortably to prevent accidental drops. And your kids can use iPad easily and safely to study or watch movies [Detachable & Adjustable Shoulder Strap] Carry your iPad conveniently wherever you are at home, at work, or on a trip. You can also hang it behind the headrest of the car seat for shared viewing [User-Friendly] Precise cutouts for easy access to the speaker, camera, buttons and other ports. And an elastic loop band beside the hand strap stores your Pencil easily, no trouble of finding your Pencil (Pencil Not Included)',
#   "CoBak Case for All-New Amazon Kindle Fire 7 Tablet 12th Generation (2022 Release) - Premium PU Leather Slim Folding Stand Shell Multiple Viewing Angles Cover with Auto Wake/Sleep - BlackONLY FIT: Designed specifically for Amazon All-New Kindle Fire 7 Tablet 12th Generation 2022 Released. Tips: DO NOT fit any other Fire devices. FEATURES: The protective tablet case is made of premium PU leather exterior and microfiber interior, makes the cover look more classic and protects your Fire 7 2022 device from being scratched. VIEWING ANGLES: Flip stand design for typing and viewing angles conveniently. Magnetic closure for easy opening and closing your Tablet. AUTO WAKE/SLEEP: The magnetic fire hd 7 case automatically wakes your device when opened and puts it to sleep when closed. And the magnetic closure keeps the cover securely closed, protecting your device from dropping out. UNCONDITIONAL 180-DAY MONEY BACK GUARANTEE: All products purchased from CoBak come with a hassle-free support service for 18 months. Whether you're a longtime customer or a new window shopper, we want you to feel confident about your purchase.",
#   'SIMPLEWAY Case for New iPad 9th/8th/7th Generation, Shockproof Light Weight Handle Stand Kids Case Super Protection Cover for iPad 10.2"/ iPad Air 10.5"/ iPad Pro 10.5"【Compatible Models】 - Durable kids case for Apple iPad 10.2" 2021 9th Generation (Model: A2602 A2603 A2604 A2605) / iPad 10.2" 2020 8th Generation (Model: A2270 A2428 A2429 A2430) / iPad 10.2" 2019 7th Generation (Model: A2197 A2200 A2198), also fit iPad Air 3rd Generation 10.5 Inch 2019 (Model: A2152 A2123 A2153 A2154) and iPad Pro 10.5 Inch 2017 (Model: A1701 A1709 A1852). It will not work for any other iPad models. 【Worry-free use】 -- Case for iPad is made of safe and environmentally friendly materials, non-toxic and non-irritating, and can be used with confidence. It can pack your tablet firmly. The case is not easy to fall off, which can better protect your tablet 【Precise Cutouts】 -- Raised bezel edges to protect the screen from scratches and shattered. All buttons, speakers, cameras, and sensors are easily accessible through precisely cut openings, and all ports are where they should be. 【Rotating handle】 -- Versatile device stands for easy handling and carrying, also can be folded into a double angle holder, convenient for typing and hands-free viewing. 【Add Interest to Life】 -- Different shapes and cute patterns will make your iPad \u200bcase more interesting. They are perfect for Christmas parties or Easter. You can put them in children’s Easter eggs or baskets as special gifts.'],
#  'similarity_scores': [0.40714088,
#   0.39314276,
#   0.3515204,
#   0.34026134,
#   0.31232083]}
