# %% [markdown]
# ### Import Dependencies

# %%
from pydantic import BaseModel, Field

from qdrant_client import QdrantClient
from qdrant_client.models import Prefetch, Filter, FieldCondition, MatchText, FusionQuery, Document


from langsmith import traceable, get_current_run_tree

from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode
from langgraph.types import Send, Command

from langchain_core.messages import AIMessage, ToolMessage, convert_to_openai_messages

from jinja2 import Template
from typing import Literal, Dict, Any, Annotated, List, Optional, Sequence
from IPython.display import Image, display
from operator import add
from openai import OpenAI

import openai

import random
import ast
import inspect
import instructor
import json

from utils.utils import get_tool_descriptions, format_ai_message

# %% [markdown]
# ### Define Retrieval Tool

# %%
@traceable(
    name="embed_query",
    run_type="embedding",
    metadata={"ls_provider": "openai", "ls_model_name": "text-embedding-3-small"}
)
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=text,
        model=model,
    )

    current_run = get_current_run_tree()

    if current_run:
        current_run.metadata["usage_metadata"] = {
            "input_tokens": response.usage.prompt_tokens,
            "total_tokens": response.usage.total_tokens
        }

    return response.data[0].embedding


@traceable(
    name="retrieve_data",
    run_type="retriever"
)
def retrieve_data(query, k=5):

    query_embedding = get_embedding(query)

    qdrant_client = QdrantClient(url="http://localhost:6333")

    results = qdrant_client.query_points(
        collection_name="Amazon-items-collection-01-hybrid-search",
        prefetch=[
            Prefetch(
                query=query_embedding,
                using="text-embedding-3-small",
                limit=20
            ),
            Prefetch(
                query=Document(
                    text=query,
                    model="qdrant/bm25"
                ),
                using="bm25",
                limit=20
            )
        ],
        query=FusionQuery(fusion="rrf"),
        limit=k,
    )

    retrieved_context_ids = []
    retrieved_context = []
    retrieved_context_ratings = []
    similarity_scores = []

    for result in results.points:
        retrieved_context_ids.append(result.payload["parent_asin"])
        retrieved_context.append(result.payload["description"])
        retrieved_context_ratings.append(result.payload["average_rating"])
        similarity_scores.append(result.score)

    return {
        "retrieved_context_ids": retrieved_context_ids,
        "retrieved_context": retrieved_context,
        "retrieved_context_ratings": retrieved_context_ratings,
        "similarity_scores": similarity_scores,
    }


@traceable(
    name="format_retrieved_context",
    run_type="prompt"
)
def process_context(context):

    formatted_context = ""

    for id, chunk, rating in zip(context["retrieved_context_ids"], context["retrieved_context"], context["retrieved_context_ratings"]):
        formatted_context += f"- ID: {id}, rating: {rating}, description: {chunk}\n"

    return formatted_context


def get_formatted_context(query: str, top_k: int = 5) -> str:

    """Get the top k context, each representing an inventory item for a given query.
    
    Args:
        query: The query to get the top k context for
        top_k: The number of context chunks to retrieve, works best with 5 or more
    
    Returns:
        A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.
    """

    context = retrieve_data(query, top_k)
    formatted_context = process_context(context)

    return formatted_context

# %% [markdown]
# ## State and Pydantic Models for structured outputs

# %%
class ToolCall(BaseModel):
    name: str
    arguments: dict

class RAGUsedContext(BaseModel):
    id: str = Field(description="ID of the item used to answer the question.")
    description: str = Field(description="Short description of the item used to answer the question.")

class AgentResponse(BaseModel):
    answer: str = Field(description="Answer to the question.")
    references: list[RAGUsedContext] = Field(description="List of items used to answer the question.")
    final_answer: bool = False
    tool_calls: List[ToolCall] = []

class State(BaseModel):
    messages: Annotated[List[Any], add] = []
    question_relevant: bool = False
    iteration: int = 0
    answer: str = ""
    available_tools: List[Dict[str, Any]] = []
    tool_calls: List[ToolCall] = []
    final_answer: bool = False
    references: Annotated[List[RAGUsedContext], add] = []

# %%
@traceable(
    name="agent_node",
    run_type="llm",
    metadata={"ls_provider": "openai", "ls_model_name": "gpt-4.1-mini"}
)
def agent_node(state: State) -> dict:

   prompt_template =  """You are a shopping assistant that can answer questions about the products in stock.

You will be given a conversation history and a list of tools you can use to answer the latest query.

<Available tools>
{{ available_tools | tojson }}
</Available tools>

When making tool calls, use this exact format:
{
    "name": "tool_name",
    "arguments": {
        "parameter1": "value1",
        "parameter2": "value2",
    }
}

CRITICAL: All parameters must go inside the "arguments" object, not at the top level of the tool call.

Examples:
- Get formatted item context:
{
    "name": "get_formatted_item_context",
    "arguments": {
        "query": "Kool kids toys.",
        "top_k": 5
    }
}

CRITICAL RULES:
- If tool_calls has values, final_answer MUST be false
(You cannot call tools and exit the graph in the same response)
- If final_answer is true, tool_calls MUST be []
(You must wait for tool results before exiting the graph)
- If you need tool results before answering, set:
tool_calls=[...], final_answer=false
- After receiving tool results, you can then set:
tool_calls=[], final_answer=true
- Use names specificly provided in the available tools. Don't add any additional text to the names.

Instructions:
- You need to answer the question based on the outputs from the tools using the available tools only.
- Do not suggest the same tool call more than once.
- If the question can be decomposed into multiple sub-questions, suggest all of them.
- If multipple tool calls can be used at once to answer the question, suggest all of them.
- Do not explain your next steps in the answer, instead use tools to answer the question.
- Never use word context and refer to it as the available products.
- You should only answer questions about the products in stock. If the question is not about the products in stock, you should ask for clarification.
- As an output you need to return the following:

* answer: The answer to the question based on your current knowledge and the tool results.
* references: The list of the indexes from the chunks returned from all tool calls that were used to answer the question. If more than one chunk was used to compile the answer from a single tool call, be sure to return all of them.
* Each reference should have an id and a short description of the item based on the retrieved context.
* final_answer: True if you have all the information needed to provide a complete answer, False otherwise.

- The answer to the question should contain detailed information about the product and should be returned with detailed specification in bullet points.
- The short description should have the name of the item.
- If the user's request requires using a tool, set tool_calls with the appropriate function names and arguments.
"""

   template = Template(prompt_template)
   
   prompt = template.render(
      available_tools=state.available_tools
   )

   messages = state.messages

   conversation = []

   for message in messages:
        conversation.append(convert_to_openai_messages(message))

   client = instructor.from_openai(OpenAI())

   response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        response_model=AgentResponse,
        messages=[{"role": "system", "content": prompt}, *conversation],
        temperature=0.5,
   )

   ai_message = format_ai_message(response)

   return {
      "messages": [ai_message],
      "tool_calls": response.tool_calls,
      "iteration": state.iteration + 1,
      "answer": response.answer,
      "final_answer": response.final_answer,
      "references": response.references
   }

# %% [markdown]
# ## Tool Router Node

# %%
def tool_router(state: State) -> str:
    """Decide whether to continue or end"""
    
    if state.final_answer:
        return "end"
    elif state.iteration > 2:
        return "end"
    elif len(state.tool_calls) > 0:
        return "tools"
    else:
        return "end"

# %% [markdown]
# ## Intent Router

# %%
class IntentRouterResponse(BaseModel):
    question_relevant: bool
    answer: str

# %%
@traceable(
    name="agent_node",
    run_type="llm",
    metadata={"ls_provider": "openai", "ls_model_name": "gpt-4.1-mini"}
)
def intent_router_node(state: State):

   prompt_template =  """You are part of a shopping assistant that can answer questions about products in stock.

Instructions:
- You will be given a conversation history with the user.
- If the latest user messgae is not relevant, return False in field "question_relevant" and set "answer" to explanation why it is not relevant.
- If the latest user message is relevant, return True in field "question_relevant" and set "answer" to "".
- You should only answer questions about the products in stock. If the question is not about the products in stock, you should ask for clarification.
"""

   template = Template(prompt_template)
   
   prompt = template.render()

   messages = state.messages

   conversation = []

   for message in messages:
        conversation.append(convert_to_openai_messages(message))

   client = instructor.from_openai(OpenAI())

   response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        response_model=IntentRouterResponse,
        messages=[{"role": "system", "content": prompt}, *conversation],
        temperature=0.5,
   )

   return {
      "question_relevant": response.question_relevant,
      "answer": response.answer
      }

# %%
def intent_router_conditional_edges(state: State):

    if state.question_relevant:
        return "agent_node"
    else:
        return "end"

# %% [markdown]
# ## Graph

# %%
workflow = StateGraph(State)

tools = [get_formatted_context]
tool_node = ToolNode(tools)
tool_descriptions = get_tool_descriptions(tools)

workflow.add_node("agent_node", agent_node)
workflow.add_node("tool_node", tool_node)
workflow.add_node("intent_router_node", intent_router_node)

workflow.add_edge(START, "intent_router_node")

workflow.add_conditional_edges(
    "intent_router_node",
    intent_router_conditional_edges,
    {
        "agent_node": "agent_node",
        "end": END
    }
)

workflow.add_conditional_edges(
    "agent_node",
    tool_router,
    {
        "tools": "tool_node",
        "end": END
    }
)

workflow.add_edge("tool_node", "agent_node")

graph = workflow.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
initial_state = {
    "messages": [{"role": "user", "content": "Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?"}],
    "available_tools": tool_descriptions
}
result = graph.invoke(initial_state)
# Out:
# Fetching 18 files:   0%|          | 0/18 [00:00<?, ?it/s]

# %%
result
# Out:
# {'messages': [{'role': 'user',
#    'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'},
#   AIMessage(content='I will check the available earphones, laptop bags, and cool items for kids in the inventory for you.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool items for kids', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}]),
#   ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super comfortable the ergonomic in-ear design can maintain a firm fit every time, ensuring proper fit and extra comfort. High-fidelity sound quality-earbud headphones provide clear top-level sound quality in the recording studio, with strong bass, strong midrange, and precise treble response, A9 can bring you delightful music. Wide compatibility-very is suitable for iPhone devices, Android smartphones, iPods, iPads, MP3 players, music speakers, and all other interface devices with 3.5mm headphone jack. High-quality service-If you have any questions, please feel free to contact us, we will reply in time. We hope you enjoy a pleasant shopping experience.\n- ID: B0BX2RDHB8, rating: 4.0, description: KNTARU Earplugs Earphones，Earphones That Look Like earplugs，Earphones Disguised as earplugs，Noise Suppression，Hearing Protection，Waterproof，for Work，Study，Fitness，Noisy Places【INCLUDES】 NRR value: 28dB ,Color: blue + orange, Connection: wired headphone,connectivity: 3.5 mm plug jack, cable ...
#   ToolMessage(content='- ID: B0BXDLW66J, rating: 4.7, description: LOVEVOOK Laptop Bag for Women 15.6 Inch Laptop Tote Work Bag Professional Leather Computer Briefcase Waterproof Handbag Shoulder Bag Large Capacity Business Teacher Office Bag Crossbody Purse,Black【Waterproof & Professional Laptop Bag】:The womens laptop bag is made of high-quality cross pattern PU leather and high-density nylon lining.it is water-resistant,scratch-resistant, wear-resistant and anti-wrinkle,easy to clean.Stretchable Key Fob Hook inside the shoulder bag can help get your keys easily,save your time.Reinforced flat bottom with 4 rivets will reduce friction and scrape of bottom of the ladies office bag,It lasts longer than other women computer tote bags 【Ideal Organizer Work Tote】:The work bags for women come with multi-compartments to meet all your work needs well. The laptop tote bag has an independent laptop compartment fits under 15.6 inch laptop and Ipad/tablet,a large main middle pocket designed for documents, book and gadgets,two small square pockets, two pen pockets,There has two side-pocket for power bank and water bottle inside.Stylish outer pocket with magnetic buckle,two zipper pockets and an anti-theft pocket,Easy access to items. 【Versatile Computer Bags for Women】:External USB port makes it easy to charge your phone while walking, or shopping,both which personalize your styles and retain a sense of chic. This womens laptop tote has length adjustable shoulder strap and handle, is suitable for different body type.The leather bags for women is ideal for daily use at shopping, office, college, business trip, school,travel etc.Perfect gift choice for anniversary, birthday, Mother\'s Day, Valentine\'s Day and Christmas. 【Perfect Size Womens Briefcase】: Size of the laptop bag is 16.9"Lx6"Wx12"H, finished with a secure zip-top closure. With a removable shoulder strap varied from 28.3 inches to maximum 49 inches and adjustable handles, You be carried in several ways as a ladies briefcase,teacher tote bag, computer bag for women or women crossbody work bag as well, convenient and comfortable. 【Additional Clutch Bag】:One more gift is a 8.7" L x 5.3" H detachable clutch purse. The additional small bag is made of soft PU leather, has smooth zippper on top closure, polyester lining inside. The purse can store change, snacks, glasses, earphones, passports, keys and cell phones.This bundle is the best gift for wife, girlfriend, mom ,daughter, families and friends\n- ID: B09QPWR9TQ, rating: 4.0, description: DRHONY Laptop Teacher Tote Bag, 15.6 Inch Computer Messenger Shoulder Bag for School, Office, BusinessMesh,Nylon Imported TONS OF STORAGE -Sized just right for you getaways, our stylish weekender bag holds Laptop, iPad , book,etc—with enough room to store teachers\' things, too OUTSIDE-POCKETS - 7 exterior pockets (4 pockets in the front, 2 side mesh pockets, a back zipper pocket) you can put notebook, pen or anything you want in. UTILITY INNER POCKETS - 6 open pockets for small items, one padded laptop compartment for your iPad, laptop or folders. Several slots for pen,Compass and etc. 2 insulated pocket to store warm food or coffee. HIGH QUALITY FABRIC - Dimension: 16”*5”*12”. Made of premium nylon with well stitches, lightweight for easy carry and durable enough to be used for a long time. VERSATILE-With adjustable and removable shoulder strap The teacher bag can be worn as crossbody or a handbag, Luggage sleeve on back easily slides over rolling luggage handles\n- ID: B092Z9CTNK, rating: 4.5, description: Rolling Laptop Bag Women with Wheels, Rolling Briefcase for Women Fits Up to 15.6 Inch Laptop Briefcase on Wheels, Water-Repellent Overnight Rolling Computer Bag with RFID Pockets, Dusty PinkMOBILE OFFICE: EMPSIGN rolling bag with laptop compartment is multifunctional in one, suitable for both business and personal travel. Fits easily into most airline overhead bins and meets most airline carry-on size requirements. The case is made of polyes ...
#   ToolMessage(content='- ID: B0B4H72GG8, rating: 4.6, description: SVGDHZK Stranger Things 4 Stickers 50pcs Cool Water Bottle Laptops Motorcycle Bicycle Skateboard Luggage Decal Graffiti Patches for Boy Girl Kid Adult (Strange)●Strange Movie 4 Stickers, perfect for kid teen adult! ●High Quality: 100% Waterproof,the sticker is made of PVC material and has sun protection and waterproof function. ●Wide Range of Applications: Perfect to personalize laptops, graffiti, Skateboards, luggage, cars, bumpers, bikes, bicycles, bedroom, travel case, Mirrors, Journals,bicycle, motorcycle, snowboard, PS4, Xbox One. Best cool stickers for teens and adult. ●Surprise Gift: Our assortment of the graffiti decals is your right choice when choosing a gift for your friends, kids. These creative patches will be the best present to make a cool room or for DIY decoration. ●We promise to provide every customer best products and service, Return of goods without reasons! If you have any problem, pls contact with us, we promise solve for you within 24h\n- ID: B09QC5G9X5, rating: 3.0, description: Smart GPS Tracker 4 Packs Water Droplets Shape Multicolor Wireless Key Finder Locator Mini GPS Tracker Anti Lost Alarm Sensor Device Remote Finder Item Finders for Kids Phone Car Wallet Luggage PetQuickly Find Items: the key finder locators can be hung on your phones, keys, bags, umbrellas, pets, cats, wallets, purses, luggage and other important items, convenient for you to find them quickly and easily, bringing a lot of convenience to your life; The tracking range is about 15 meters Convenient to Use: download the APP from the user\'s manual and it will work, the GPS trackers for kids are easy for your operation, and you just need to press the button for a few seconds, then the receiver will sound beeps, after that you can use your cellphone to search and connect to the device, if you lost your phone, you can double press the button, then your phone would alarm Timely Reminders: when you install these GPS trackers for dogs behind your phones, keys and other things that are easy to lose, they will sound or flash if your keys leave you beyond a certain range, informing you to find the lost items in time, besides they and your phone will alarm together when disconnecting, and this function could be turned off in setting Ample for Your Various Needs: the package includes 4 packs of kid tracker devices, sufficient for your daily application, you can also share them with others; Besides, the 3 different colors can offer you more choices Small Size and Lightweight: the mini GPS tracker are approx. 5.2 x 3.1 x 1.1 cm/ 2.05 x 1.22 x 0.43 inches in size and light in weight, allowing you to take them around easily without giving you much burden, so you can hang them on your kid\'s schoolbag or pet collar, nice for daily storage without occupying much space\n- ID: B09NKPPYC2, rating: 4.6, description: 100pcs Cool Double Style Arcane: League of Legends Cartoon Anime Game Decal Stickers for Kids Teens Adult Game Lovers for Water Bottles Laptop Skateboard Luggage Computer Guitar Sticker👍 [style description] this is a 100 piece sticker, including jinx, VI, jayce, ekko, Viktor, Caitlyn kiramman, silco and other main characters. It consists of two different styles of arcane, of which 50 are bright membranes and 50 are sub membranes. Although the styles are different, each one is unique, and they are deeply loved by lol lovers. We believe these stickers will make your life more colorful. 👍[material selection] the sticker is made of environmentally friendly vinyl. At the same time, w.p.s 2.0 waterproof membrane is adopted, which makes the waterproof performance more reliable. We promise that the sticker will not be toxic or have adverse effects on human body. (do not eat!) 👍[applicable population]Children, adolescents, adolescents, adults and all people with independent behavior ability. The opening method of the sticker is very convenient and does not need to spend a lot of effor ...
#   AIMessage(content='Here are some options for you and your family:\n\nEarphones for you:\n- aeac Wireless Earbuds: Wireless Bluetooth, IPX5 Waterproof, built-in mic, white color.\n- 100SEASHELL Long Cord Wired Earbuds: No microphone, noise isolating, enhanced bass, compatible with multiple devices.\n- 6 Pack Earbuds Headphone Wired with Microphone: Noise isolating, in-ear bass earbuds, compatible with iPhone/Android/PC.\n- KNTARU Earplugs Earphones: Earphones disguised as earplugs, noise suppression, waterproof, wired with 3.5mm jack.\n\nLaptop bags for your wife:\n- LOVEVOOK Laptop Bag for Women: Fits 15.6 inch laptop, waterproof, professional leather, multiple compartments, USB port, black color.\n- DRHONY Laptop Teacher Tote Bag: 15.6 inch, nylon, multiple compartments, lightweight, adjustable/removable shoulder strap.\n- Rolling Laptop Bag Women with Wheels: Fits 15.6 inch laptop, waterproof, RFID pockets, dusty pink color.\n- Liokesa Travel Laptop Backpack for Men: 15.6 inch, USB charging port, anti-theft, water resistant, grey color.\n- ZOMFELT Rolling Backpack: 17.3 inch laptop, wheels, extra packing bags, black color.\n\nCool items for kids:\n- SVGDHZK Stranger Things 4 Stickers: 50pcs waterproof stickers, perfect for kids and teens.\n- Smart GPS Tracker 4 Packs: Wireless key finder locator, mini GPS tracker for kids, multicolor.\n- 100pcs Cool Double Style Arcane Stickers: Cartoon anime game decals for kids and teens.\n- 100Pcs Cool Neon Light Stickers: Waterproof neon stickers pack for kids and teens.\n- Candy Bila Kids Headphones: Wired headphones for kids with microphone, volume limiter, foldable, pink gradient.\n\nPlease let me know if you want detailed specifications or to purchase any of these items.', additional_kwargs={}, response_metadata={})],
#  'question_relevant': True,
#  'iteration': 2,
#  'answer': 'Here are some options for you and your family:\n\nEarphones for you:\n- aeac Wireless Earbuds: Wireless Bluetooth, IPX5 Waterproof, built-in mic, white color.\n- 100SEASHELL Long Cord Wired Earbuds: No microphone, noise isolating, enhanced bass, compatible with multiple devices.\n- 6 Pack Earbuds Headphone Wired with Microphone: Noise isolating, in-ear bass earbuds, compatible with iPhone/Android/PC.\n- KNTARU Earplugs Earphones: Earphones disguised as earplugs, noise suppression, waterproof, wired with 3.5mm jack.\n\nLaptop bags for your wife:\n- LOVEVOOK Laptop Bag for Women: Fits 15.6 inch laptop, waterproof, professional leather, multiple compartments, USB port, black color.\n- DRHONY Laptop Teacher Tote Bag: 15.6 inch, nylon, multiple compartments, lightweight, adjustable/removable shoulder strap.\n- Rolling Laptop Bag Women with Wheels: Fits 15.6 inch laptop, waterproof, RFID pockets, dusty pink color.\n- Liokesa Travel Laptop Backpack for Men: 15.6 inch, USB charging port, anti-theft, water resistant, grey color.\n- ZOMFELT Rolling Backpack: 17.3 inch laptop, wheels, extra packing bags, black color.\n\nCool items for kids:\n- SVGDHZK Stranger Things 4 Stickers: 50pcs waterproof stickers, perfect for kids and teens.\n- Smart GPS Tracker 4 Packs: Wireless key finder locator, mini GPS tracker for kids, multicolor.\n- 100pcs Cool Double Style Arcane Stickers: Cartoon anime game decals for kids and teens.\n- 100Pcs Cool Neon Light Stickers: Waterproof neon stickers pack for kids and teens.\n- Candy Bila Kids Headphones: Wired headphones for kids with microphone, volume limiter, foldable, pink gradient.\n\nPlease let me know if you want detailed specifications or to purchase any of these items.',
#  'available_tools': [{'name': 'get_formatted_context',
#    'description': 'Get the top k context, each representing an inventory item for a given query.',
#    'parameters': {'type': 'object',
#     'properties': {'query': {'type': 'string',
#       'description': 'The query to get the top k context for'},
#      'top_k': {'type': 'integer',
#       'description': 'The number of context chunks to retrieve, works best with 5 or more',
#       'default': 5}}},
#    'required': ['query'],
#    'returns': {'type': 'string',
#     'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}],
#  'tool_calls': [],
#  'final_answer': True,
#  'references': [RAGUsedContext(id='B0BBFNHMYX', description='aeac Wireless Earbuds'),
#   RAGUsedContext(id='B09PYK37K4', description='100SEASHELL Long Cord Wired Earbuds'),
#   RAGUsedContext(id='B09Y5DZW52', description='6 Pack Earbuds Headphone Wired with Microphone'),
#   RAGUsedContext(id='B0BX2RDHB8', description='KNTARU Earplugs Earphones'),
#   RAGUsedContext(id='B0BXDLW66J', description='LOVEVOOK Laptop Bag for Women'),
#   RAGUsedContext(id='B09QPWR9TQ', description='DRHONY Laptop Teacher Tote Bag'),
#   RAGUsedContext(id='B092Z9CTNK', description='Rolling Laptop Bag Women with Wheels'),
#   RAGUsedContext(id='B0C49XLZW1', description='Liokesa Travel Laptop Backpack for Men'),
#   RAGUsedContext(id='B0B2RKB1HP', description='ZOMFELT Rolling Backpack'),
#   RAGUsedContext(id='B0B4H72GG8', description='SVGDHZK Stranger Things 4 Stickers'),
#   RAGUsedContext(id='B09QC5G9X5', description='Smart GPS Tracker 4 Packs'),
#   RAGUsedContext(id='B09NKPPYC2', description='100pcs Cool Double Style Arcane Stickers'),
#   RAGUsedContext(id='B0BR5FTDDK', description='100Pcs Cool Neon Light Stickers'),
#   RAGUsedContext(id='B0C7H9P1HX', description='Candy Bila Kids Headphones')]}

# %%
print(result["answer"])
# Out:
# Here are some options for you and your family:
#
# Earphones for you:
# - aeac Wireless Earbuds: Wireless Bluetooth, IPX5 Waterproof, built-in mic, white color.
# - 100SEASHELL Long Cord Wired Earbuds: No microphone, noise isolating, enhanced bass, compatible with multiple devices.
# - 6 Pack Earbuds Headphone Wired with Microphone: Noise isolating, in-ear bass earbuds, compatible with iPhone/Android/PC.
# - KNTARU Earplugs Earphones: Earphones disguised as earplugs, noise suppression, waterproof, wired with 3.5mm jack.
#
# Laptop bags for your wife:
# - LOVEVOOK Laptop Bag for Women: Fits 15.6 inch laptop, waterproof, professional leather, multiple compartments, USB port, black color.
# - DRHONY Laptop Teacher Tote Bag: 15.6 inch, nylon, multiple compartments, lightweight, adjustable/removable shoulder strap.
# - Rolling Laptop Bag Women with Wheels: Fits 15.6 inch laptop, waterproof, RFID pockets, dusty pink color.
# - Liokesa Travel Laptop Backpack for Men: 15.6 inch, USB charging port, anti-theft, water resistant, grey color.
# - ZOMFELT Rolling Backpack: 17.3 inch laptop, wheels, extra packing bags, black color.
#
# Cool items for kids:
# - SVGDHZK Stranger Things 4 Stickers: 50pcs waterproof stickers, perfect for kids and teens.
# - Smart GPS Tracker 4 Packs: Wireless key finder locator, mini GPS tracker for kids, multicolor.
# - 100pcs Cool Double Style Arcane Stickers: Cartoon anime game decals for kids and teens.
# - 100Pcs Cool Neon Light Stickers: Waterproof neon stickers pack for kids and teens.
# - Candy Bila Kids Headphones: Wired headphones for kids with microphone, volume limiter, foldable, pink gradient.
#
# Please let me know if you want detailed specifications or to purchase any of these items.

# %%
initial_state = {
    "messages": [{"role": "user", "content": "Can you fix my roof?"}],
    "available_tools": tool_descriptions
}
result = graph.invoke(initial_state)

# %%
result
# Out:
# {'messages': [{'role': 'user', 'content': 'Can you fix my roof?'}],
#  'question_relevant': False,
#  'answer': 'Your question is not relevant to the products in stock. I can assist you with questions about products, but I cannot fix your roof. Please let me know if you have any questions about the products available.',
#  'available_tools': [{'name': 'get_formatted_context',
#    'description': 'Get the top k context, each representing an inventory item for a given query.',
#    'parameters': {'type': 'object',
#     'properties': {'query': {'type': 'string',
#       'description': 'The query to get the top k context for'},
#      'top_k': {'type': 'integer',
#       'description': 'The number of context chunks to retrieve, works best with 5 or more',
#       'default': 5}}},
#    'required': ['query'],
#    'returns': {'type': 'string',
#     'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}],
#  'references': []}
