# %% [markdown]
# ### Import Dependencies

# %%
from pydantic import BaseModel, Field

from qdrant_client import QdrantClient
from qdrant_client.models import Prefetch, Filter, FieldCondition, MatchAny, FusionQuery, Document


from langsmith import traceable, get_current_run_tree

from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode
from langgraph.types import Send, Command

from langchain_core.messages import AIMessage, ToolMessage, convert_to_openai_messages

from jinja2 import Template
from typing import Literal, Dict, Any, Annotated, List, Optional, Sequence
from IPython.display import Image, display
from operator import add
from openai import OpenAI

import openai

import random
import ast
import inspect
import instructor
import json

from utils.utils import get_tool_descriptions, format_ai_message

# %% [markdown]
# ### Define Retrieval Tool

# %%
@traceable(
    name="embed_query",
    run_type="embedding",
    metadata={"ls_provider": "openai", "ls_model_name": "text-embedding-3-small"}
)
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=text,
        model=model,
    )

    current_run = get_current_run_tree()

    if current_run:
        current_run.metadata["usage_metadata"] = {
            "input_tokens": response.usage.prompt_tokens,
            "total_tokens": response.usage.total_tokens
        }

    return response.data[0].embedding


@traceable(
    name="retrieve_data",
    run_type="retriever"
)
def retrieve_data(query, k=5):

    query_embedding = get_embedding(query)

    qdrant_client = QdrantClient(url="http://localhost:6333")

    results = qdrant_client.query_points(
        collection_name="Amazon-items-collection-01-hybrid-search",
        prefetch=[
            Prefetch(
                query=query_embedding,
                using="text-embedding-3-small",
                limit=20
            ),
            Prefetch(
                query=Document(
                    text=query,
                    model="qdrant/bm25"
                ),
                using="bm25",
                limit=20
            )
        ],
        query=FusionQuery(fusion="rrf"),
        limit=k,
    )

    retrieved_context_ids = []
    retrieved_context = []
    retrieved_context_ratings = []
    similarity_scores = []

    for result in results.points:
        retrieved_context_ids.append(result.payload["parent_asin"])
        retrieved_context.append(result.payload["description"])
        retrieved_context_ratings.append(result.payload["average_rating"])
        similarity_scores.append(result.score)

    return {
        "retrieved_context_ids": retrieved_context_ids,
        "retrieved_context": retrieved_context,
        "retrieved_context_ratings": retrieved_context_ratings,
        "similarity_scores": similarity_scores,
    }


@traceable(
    name="format_retrieved_context",
    run_type="prompt"
)
def process_context(context):

    formatted_context = ""

    for id, chunk, rating in zip(context["retrieved_context_ids"], context["retrieved_context"], context["retrieved_context_ratings"]):
        formatted_context += f"- ID: {id}, rating: {rating}, description: {chunk}\n"

    return formatted_context


def get_formatted_context(query: str, top_k: int = 5) -> str:

    """Get the top k context, each representing an inventory item for a given query.
    
    Args:
        query: The query to get the top k context for
        top_k: The number of context chunks to retrieve, works best with 5 or more
    
    Returns:
        A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.
    """

    context = retrieve_data(query, top_k)
    formatted_context = process_context(context)

    return formatted_context

# %% [markdown]
# ### Define Reviews Retrieval Tool

# %%
@traceable(
    name="retrieve_reviews_data",
    run_type="retriever"
)
def retrieve_reviews_data(query, item_list, k=5):

    query_embedding = get_embedding(query)

    qdrant_client = QdrantClient(url="http://localhost:6333")

    results = qdrant_client.query_points(
        collection_name="Amazon-items-collection-01-reviews",
        prefetch=[
            Prefetch(
                query=query_embedding,
                filter=Filter(
                    must=[
                        FieldCondition(
                            key="parent_asin",
                            match=MatchAny(
                                any=item_list
                            )
                        )
                    ]
                ),
                limit=20
            )
        ],
        query=FusionQuery(fusion="rrf"),
        limit=k
    )

    retrieved_context_ids = []
    retrieved_context = []
    similarity_scores = []

    for result in results.points:
        retrieved_context_ids.append(result.payload["parent_asin"])
        retrieved_context.append(result.payload["text"])
        similarity_scores.append(result.score)

    return {
        "retrieved_context_ids": retrieved_context_ids,
        "retrieved_context": retrieved_context,
        "similarity_scores": similarity_scores,
    }


@traceable(
    name="format_retrieved_reviews_context",
    run_type="prompt"
)
def process_reviews_context(context):

    formatted_context = ""

    for id, chunk in zip(context["retrieved_context_ids"], context["retrieved_context"]):
        formatted_context += f"- ID: {id}, review: {chunk}\n"

    return formatted_context


def get_formatted_reviews_context(query: str, item_list: list, top_k: int = 5) -> str:

    """Get the top k reviews matching a query for a list of prefiltered items.
    
    Args:
        query: The query to get the top k reviews for
        item_list: The list of item IDs to prefilter for before running the query
        top_k: The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered
    
    Returns:
        A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.
    """

    context = retrieve_reviews_data(query, item_list, top_k)
    formatted_context = process_reviews_context(context)

    return formatted_context

# %% [markdown]
# ## State and Pydantic Models for structured outputs

# %%
class ToolCall(BaseModel):
    name: str
    arguments: dict

class RAGUsedContext(BaseModel):
    id: str = Field(description="ID of the item used to answer the question.")
    description: str = Field(description="Short description of the item used to answer the question.")

class AgentResponse(BaseModel):
    answer: str = Field(description="Answer to the question.")
    references: list[RAGUsedContext] = Field(description="List of items used to answer the question.")
    final_answer: bool = False
    tool_calls: List[ToolCall] = []

class State(BaseModel):
    messages: Annotated[List[Any], add] = []
    question_relevant: bool = False
    iteration: int = 0
    answer: str = ""
    available_tools: List[Dict[str, Any]] = []
    tool_calls: List[ToolCall] = []
    final_answer: bool = False
    references: Annotated[List[RAGUsedContext], add] = []

# %%
@traceable(
    name="agent_node",
    run_type="llm",
    metadata={"ls_provider": "openai", "ls_model_name": "gpt-4.1-mini"}
)
def agent_node(state: State) -> dict:

   prompt_template =  """You are a shopping assistant that can answer questions about the products in stock.

You will be given a conversation history and a list of tools you can use to answer the latest query.

<Available tools>
{{ available_tools | tojson }}
</Available tools>

When making tool calls, use this exact format:
{
    "name": "tool_name",
    "arguments": {
        "parameter1": "value1",
        "parameter2": "value2",
    }
}

CRITICAL: All parameters must go inside the "arguments" object, not at the top level of the tool call.

Examples:
- Get formatted item context:
{
    "name": "get_formatted_item_context",
    "arguments": {
        "query": "Kool kids toys.",
        "top_k": 5
    }
}

- Get formatted user reviews:
    {
        "name": "get_formatted_reviews_context",
        "arguments": {
            "query": "Durable.",
            "item_list": ["123", "456"],
            "top_k": 5
        }
    }

CRITICAL RULES:
- If tool_calls has values, final_answer MUST be false
(You cannot call tools and exit the graph in the same response)
- If final_answer is true, tool_calls MUST be []
(You must wait for tool results before exiting the graph)
- If you need tool results before answering, set:
tool_calls=[...], final_answer=false
- After receiving tool results, you can then set:
tool_calls=[], final_answer=true
- When suggesting tool calls, use names specificly provided in the available tools. Don't add any additional text to the names. You can only use get_formatted_item_context or get_formatted_reviews_context for tool names.

Instructions:
- You need to answer the question based on the outputs from the tools using the available tools only.
- Do not suggest the same tool call more than once.
- If the question can be decomposed into multiple sub-questions, suggest all of them.
- If multipple tool calls can be used at once to answer the question, suggest all of them.
- Do not explain your next steps in the answer, instead use tools to answer the question.
- Never use word context and refer to it as the available products.
- If using reviews data, make sure to match reviews to item IDs and summarise them instead of returning them as is, clearly split reviews from general item specification.
- You should only answer questions about the products in stock. If the question is not about the products in stock, you should ask for clarification.
- As an output you need to return the following:

* answer: The answer to the question based on your current knowledge and the tool results.
* references: The list of the indexes from the chunks returned from all tool calls that were used to answer the question. If more than one chunk was used to compile the answer from a single tool call, be sure to return all of them.
* Each reference should have an id and a short description of the item based on the retrieved context.
* final_answer: True if you have all the information needed to provide a complete answer, False otherwise.

- The answer to the question should contain detailed information about the product and should be returned with detailed specification in bullet points.
- The short description should have the name of the item.
- If the user's request requires using a tool, set tool_calls with the appropriate function names and arguments.
"""

   template = Template(prompt_template)
   
   prompt = template.render(
      available_tools=state.available_tools
   )

   messages = state.messages

   conversation = []

   for message in messages:
        conversation.append(convert_to_openai_messages(message))

   client = instructor.from_openai(OpenAI())

   response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        response_model=AgentResponse,
        messages=[{"role": "system", "content": prompt}, *conversation],
        temperature=0.5,
   )

   ai_message = format_ai_message(response)

   return {
      "messages": [ai_message],
      "tool_calls": response.tool_calls,
      "iteration": state.iteration + 1,
      "answer": response.answer,
      "final_answer": response.final_answer,
      "references": response.references
   }

# %% [markdown]
# ## Tool Router Node

# %%
def tool_router(state: State) -> str:
    """Decide whether to continue or end"""
    
    if state.final_answer:
        return "end"
    elif state.iteration > 2:
        return "end"
    elif len(state.tool_calls) > 0:
        return "tools"
    else:
        return "end"

# %% [markdown]
# ## Intent Router

# %%
class IntentRouterResponse(BaseModel):
    question_relevant: bool
    answer: str

# %%
@traceable(
    name="agent_node",
    run_type="llm",
    metadata={"ls_provider": "openai", "ls_model_name": "gpt-4.1-mini"}
)
def intent_router_node(state: State):

   prompt_template =  """You are part of a shopping assistant that can answer questions about products in stock.

Instructions:
- You will be given a conversation history with the user.
- If the latest user messgae is not relevant, return False in field "question_relevant" and set "answer" to explanation why it is not relevant.
- If the latest user message is relevant, return True in field "question_relevant" and set "answer" to "".
- You should only answer questions about the products in stock. If the question is not about the products in stock, you should ask for clarification.
"""

   template = Template(prompt_template)
   
   prompt = template.render()

   messages = state.messages

   conversation = []

   for message in messages:
        conversation.append(convert_to_openai_messages(message))

   client = instructor.from_openai(OpenAI())

   response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        response_model=IntentRouterResponse,
        messages=[{"role": "system", "content": prompt}, *conversation],
        temperature=0.5,
   )

   return {
      "question_relevant": response.question_relevant,
      "answer": response.answer
      }

# %%
def intent_router_conditional_edges(state: State):

    if state.question_relevant:
        return "agent_node"
    else:
        return "end"

# %% [markdown]
# ## Graph

# %%
workflow = StateGraph(State)

tools = [get_formatted_context, get_formatted_reviews_context]
tool_node = ToolNode(tools)
tool_descriptions = get_tool_descriptions(tools)

workflow.add_node("agent_node", agent_node)
workflow.add_node("tool_node", tool_node)
workflow.add_node("intent_router_node", intent_router_node)

workflow.add_edge(START, "intent_router_node")

workflow.add_conditional_edges(
    "intent_router_node",
    intent_router_conditional_edges,
    {
        "agent_node": "agent_node",
        "end": END
    }
)

workflow.add_conditional_edges(
    "agent_node",
    tool_router,
    {
        "tools": "tool_node",
        "end": END
    }
)

workflow.add_edge("tool_node", "agent_node")

graph = workflow.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Persistent State

# %%
from langgraph.checkpoint.postgres import PostgresSaver

# %% [markdown]
# ### Multiturn conversation

# %%
state = {
    "messages": [{"role": "user", "content": "Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?"}],
    "available_tools": tool_descriptions
}
config = {"configurable": {"thread_id": "test000011"}}

with PostgresSaver.from_conn_string("postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db") as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    answer_1 = graph.invoke(state, config=config)

# %%
answer_1
# Out:
# {'messages': [{'role': 'user',
#    'content': 'Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?'},
#   AIMessage(content='I will find earphones and waterproof speakers for you along with positive and negative user reviews for each item.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'waterproof speakers', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]),
#   ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super comfortable the ergonomic in-ear design can maintain a firm fit every time, ensuring proper fit and extra comfort. High-fidelity sound quality-earbud headphones provide clear top-level sound quality in the recording studio, with strong bass, strong midrange, and precise treble response, A9 can bring you delightful music. Wide compatibility-very is suitable for iPhone devices, Android smartphones, iPods, iPads, MP3 players, music speakers, and all other interface devices with 3.5mm headphone jack. High-quality service-If you have any questions, please feel free to contact us, we will reply in time. We hope you enjoy a pleasant shopping experience.\n- ID: B0BX2RDHB8, rating: 4.0, description: KNTARU Earplugs Earphones，Earphones That Look Like earplugs，Earphones Disguised as earplugs，Noise Suppression，Hearing Protection，Waterproof，for Work，Study，Fitness，Noisy Places【INCLUDES】 NRR value: 28dB ,Color: blue + orange, Connection: wired headphone,connectivity: 3.5 mm plug jack, cable ...
#   ToolMessage(content='- ID: B0BXKHLT54, rating: 4.5, description: comiso IPX7 Waterproof Bluetooth Speakers, Portable Wireless Speakers with Rich Bass HD Sound, Small Compact Floating Speaker with 20H Playtime for Beach, Pool, Shower, Outdoor Travel - Blue【 IP67 WATERPROOF and DUSTPROOF 】- COMISO C16 Waterproof bluetooth speaker is not only IPX7 waterproof, but also dustproof. Can be submerged underwater to 1 meter for 30 minutes. Surprisingly it can also float on water. To be used as the perfect shower speaker, beach speaker, outdoor speaker. 【 POWERFUL SOUND WITHOUT DISTORTION 】- Although COMISO C16 bluetooth speaker has a ultra-compact size, it can provide you with crisp and clean sound without distortion. Additionally has a microphone installed, so you can make a high-quality phone call with perfect sound by clicking once the play button. 【 STEREO PAIRING for MORE IMMERSIVE MUSIC 】- With true wireless pairing function, you can connect two speakers via Bluetooth to experience synchronized setero sound. Advanced bluetooth 5.0 technology to provide faster and more stable conection. 【 LONG BATTERY LIFE 】- Built-in rechargeable battery supports up to 20 hours of playtime at medium volume under a full charge. This portable speaker can hang with you all day and night. And it can be fully charged in 2.5 hours via Type-C cable. 【 Ultra-PORTABLE DESIGN 】- Weight only 195 grams, this small speaker allows you to take it anywhere. Plus, the durable waterproof fabric material and rugged rubber housing are ready for all outdoor adventurers.\n- ID: B09Y96HMY2, rating: 4.2, description: LENRUE Portable Bluetooth Speakers, IPX7 Waterproof Wireless Speaker with 20W Stereo Sound, Rich Bass, 20H Playtime, Built-in Mic, Outdoor Speaker for Party Pool Camping【Excellent Sound Quality】20W Dual high-performance power drivers deliver shocking sound without distortion even at the max volume, bringing you an immersive listening experience, and crystal clear highs. Press the Bass+ button of the bluetooth speaker that booms and projects music that energizes and sings with solid lows at any volume. 【IPX7 Waterproof Bluetooth Speaker】LENRUE wireless speakers have designed and provided fully waterproof of highest protection degree of IPX7, just as good outside as it is inside. Take it to the shower, pool, beach, hiking, or park, and you can listen to your music while you and your friends enjoy the sun. 【Lightweight & Ultra Portable Speaker】The durable exterior and strap make this speaker ready for just about anything, easy to carry your music to wherever. Hang it from your backpack, from your wrist, or your bike, and the speaker will project the sound down to where you are. 【Hands Free Calling】The wireless bluetooth speaker built-in microphone lets you take calls when connected to your phone via Bluetooth, or ask Alexa to set timers, check the news, control your smart home devices, and more. 【Incredible Bluetooth V5.0 Technology】LENRUE small bluetooth speakers use advanced antenna design with Bluetooth 5.0, connect your phone, tablet, or laptop from up to 100 feet away, provides more stable signal, faster connection and lower latency. Offer 12-month & Hassle-free 7x24 hours after-sale service.\n- ID: B09ZNKRFSC, rating: 4.7, description: JBL Flip 6 - Waterproof Portable Bluetooth Speaker, Powerful Sound and deep bass, IPX7 Waterproof, 12 Hours of Playtime with Megen Hardshell CaseWATERPROOF BLUETOOTH SPEAKER: The Flip 6 Bluetooth wireless speaker has an innovative IPX7 waterproof design that allows you to fearlessly emerge the entire speaker into the water a few feet deep. Are you already excited to try it out? 12 Hours of Playtime Don’t sweat the small stuff like charging your battery. JBL Flip 6 gives you up to 12 hours of playtime on a single charge. Hike up the fun with PartyBoost PartyBoost allows you to pair two JBL PartyBoost-compatible speakers together for stereo sound or link multiple JBL PartyBoost-compatible speakers to truly pump up your part ...
#   AIMessage(content='Here are some earphones and waterproof speakers available:\n\nEarphones:\n1. aeac Wireless Earbuds\n- Wireless Bluetooth\n- IPX5 Waterproof\n- Built-in Mic\n- Color: White\n\n2. 100SEASHELL Long Cord Wired Earbuds\n- No Microphone\n- Noise isolating\n- Bass blocking\n- 3.5mm stereo headset\n- Compatible with multiple devices\n\n3. 6 Pack Earbuds Headphone Wired with Microphone\n- Noise isolating in-ear\n- Built-in microphone and volume control\n- Compatible with iPhone, Android, PC\n\n4. KNTARU Earplugs Earphones\n- Wired\n- Noise suppression\n- Waterproof\n- Suitable for work, study, fitness\n\nWaterproof Speakers:\n1. comiso IPX7 Waterproof Bluetooth Speakers\n- IP67 Waterproof and dustproof\n- Portable, compact, floating\n- 20 hours playtime\n- Bluetooth 5.0\n\n2. LENRUE Portable Bluetooth Speakers\n- IPX7 Waterproof\n- 20W stereo sound\n- 20 hours playtime\n- Built-in mic\n\n3. JBL Flip 6\n- IPX7 Waterproof\n- 12 hours playtime\n- Bluetooth 5.1\n- Powerful sound and deep bass\n\n4. BOGASING Bluetooth Speakers M4\n- 40W deep bass\n- IPX7 Waterproof\n- Bluetooth 5.0\n- Built-in mic\n\n5. Tronsmart Bang Mini Portable Bluetooth Speaker\n- 50W wireless stereo sound\n- IPX6 Waterproof\n- Bluetooth 5.3\n- Beat-driven light show\n- 15 hours playtime\n\nNext, I will gather positive and negative user reviews for these items.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_reviews_context', 'args': {'query': 'positive', 'item_list': ['B0BBFNHMYX', 'B09PYK37K4', 'B09Y5DZW52', 'B0BX2RDHB8', 'B0BXKHLT54', 'B09Y96HMY2', 'B09ZNKRFSC', 'B0C999S8YM', 'B0B93MRTWF'], 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_reviews_context', 'args': {'query': 'negative', 'item_list': ['B0BBFNHMYX', 'B09PYK37K4', 'B09Y5DZW52', 'B0BX2RDHB8', 'B0BXKHLT54', 'B09Y96HMY2', 'B09ZNKRFSC', 'B0C999S8YM', 'B0B93MRTWF'], 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]),
#   ToolMessage(content='- ID: B0C999S8YM, review: good i like it\n- ID: B09PYK37K4, review: good product Good product overall.  No issues....\n- ID: B0B93MRTWF, review: Good for the price Good for the price\n- ID: B09Y96HMY2, review: Great Works well\n- ID: B09Y96HMY2, review: Very pleased Great output. Very happy with this speaker\n', name='get_formatted_reviews_context', tool_call_id='call_0'),
#   ToolMessage(content="- ID: B0C999S8YM, review: good i like it\n- ID: B09PYK37K4, review: good product Good product overall.  No issues....\n- ID: B0BBFNHMYX, review: Nada Esperaba algo mejor no me gusto\n- ID: B09PYK37K4, review: Of course.. Left doesn't work\n- ID: B0BBFNHMYX, review: Sent back Didn’t seem to charge as should\n", name='get_formatted_reviews_context', tool_call_id='call_1'),
#   AIMessage(content='Here are the earphones and waterproof speakers with positive and negative user reviews:\n\nEarphones:\n1. aeac Wireless Earbuds\n- Wireless Bluetooth\n- IPX5 Waterproof\n- Built-in Mic\n- Color: White\n- Positive: No specific positive review found.\n- Negative: Some users reported charging issues and dissatisfaction.\n\n2. 100SEASHELL Long Cord Wired Earbuds\n- No Microphone\n- Noise isolating\n- Bass blocking\n- 3.5mm stereo headset\n- Compatible with multiple devices\n- Positive: Good product overall, no issues reported.\n- Negative: Left earbud sometimes does not work.\n\n3. 6 Pack Earbuds Headphone Wired with Microphone\n- Noise isolating in-ear\n- Built-in microphone and volume control\n- Compatible with iPhone, Android, PC\n- Positive: No specific positive review found.\n- Negative: No specific negative review found.\n\n4. KNTARU Earplugs Earphones\n- Wired\n- Noise suppression\n- Waterproof\n- Suitable for work, study, fitness\n- Positive: No specific positive review found.\n- Negative: No specific negative review found.\n\nWaterproof Speakers:\n1. comiso IPX7 Waterproof Bluetooth Speakers\n- IP67 Waterproof and dustproof\n- Portable, compact, floating\n- 20 hours playtime\n- Bluetooth 5.0\n- Positive: No specific positive review found.\n- Negative: No specific negative review found.\n\n2. LENRUE Portable Bluetooth Speakers\n- IPX7 Waterproof\n- 20W stereo sound\n- 20 hours playtime\n- Built-in mic\n- Positive: Great performance, very pleased users.\n- Negative: No specific negative review found.\n\n3. JBL Flip 6\n- IPX7 Waterproof\n- 12 hours playtime\n- Bluetooth 5.1\n- Powerful sound and deep bass\n- Positive: No specific positive review found.\n- Negative: No specific negative review found.\n\n4. BOGASING Bluetooth Speakers M4\n- 40W deep bass\n- IPX7 Waterproof\n- Bluetooth 5.0\n- Built-in mic\n- Positive: Good speaker, users like it.\n- Negative: No specific negative review found.\n\n5. Tronsmart Bang Mini Portable Bluetooth Speaker\n- 50W wireless stereo sound\n- IPX6 Waterproof\n- Bluetooth 5.3\n- Beat-driven light show\n- 15 hours playtime\n- Positive: Good value for the price.\n- Negative: No specific negative review found.\n\nIf you want more detailed reviews or information on any specific item, please let me know!', additional_kwargs={}, response_metadata={}),
#   {'role': 'user',
#    'content': 'Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?'},
#   AIMessage(content='Here are some earphones and waterproof speakers available along with positive and negative user reviews for each:\n\nEarphones:\n1. aeac Wireless Earbuds\n- Wireless Bluetooth\n- IPX5 Waterproof\n- Built-in Mic\n- Color: White\n- Positive: No specific positive review found.\n- Negative: Some users reported charging issues and dissatisfaction.\n\n2. 100SEASHELL Long Cord Wired Earbuds\n- No Microphone\n- Noise isolating\n- Bass blocking\n- 3.5mm stereo headset\n- Compatible with multiple devices\n- Positive: Good product overall, no issues reported.\n- Negative: Left earbud sometimes does not work.\n\n3. 6 Pack Earbuds Headphone Wired with Microphone\n- Noise isolating in-ear\n- Built-in microphone and volume control\n- Compatible with iPhone, Android, PC\n- Positive: No specific positive review found.\n- Negative: No specific negative review found.\n\n4. KNTARU Earplugs Earphones\n- Wired\n- Noise suppression\n- Waterproof\n- Suitable for work, study, fitness\n- Positive: No specific positive review found.\n- Negative: No specific negative review found.\n\nWaterproof Speakers:\n1. comiso IPX7 Waterproof Bluetooth Speakers\n- IP67 Waterproof and dustproof\n- Portable, compact, floating\n- 20 hours playtime\n- Bluetooth 5.0\n- Positive: No specific positive review found.\n- Negative: No specific negative review found.\n\n2. LENRUE Portable Bluetooth Speakers\n- IPX7 Waterproof\n- 20W stereo sound\n- 20 hours playtime\n- Built-in mic\n- Positive: Great performance, very pleased users.\n- Negative: No specific negative review found.\n\n3. JBL Flip 6\n- IPX7 Waterproof\n- 12 hours playtime\n- Bluetooth 5.1\n- Powerful sound and deep bass\n- Positive: No specific positive review found.\n- Negative: No specific negative review found.\n\n4. BOGASING Bluetooth Speakers M4\n- 40W deep bass\n- IPX7 Waterproof\n- Bluetooth 5.0\n- Built-in mic\n- Positive: Good speaker, users like it.\n- Negative: No specific negative review found.\n\n5. Tronsmart Bang Mini Portable Bluetooth Speaker\n- 50W wireless stereo sound\n- IPX6 Waterproof\n- Bluetooth 5.3\n- Beat-driven light show\n- 15 hours playtime\n- Positive: Good value for the price.\n- Negative: No specific negative review found.\n\nIf you want more detailed reviews or information on any specific item, please let me know!', additional_kwargs={}, response_metadata={})],
#  'question_relevant': True,
#  'iteration': 4,
#  'answer': 'Here are some earphones and waterproof speakers available along with positive and negative user reviews for each:\n\nEarphones:\n1. aeac Wireless Earbuds\n- Wireless Bluetooth\n- IPX5 Waterproof\n- Built-in Mic\n- Color: White\n- Positive: No specific positive review found.\n- Negative: Some users reported charging issues and dissatisfaction.\n\n2. 100SEASHELL Long Cord Wired Earbuds\n- No Microphone\n- Noise isolating\n- Bass blocking\n- 3.5mm stereo headset\n- Compatible with multiple devices\n- Positive: Good product overall, no issues reported.\n- Negative: Left earbud sometimes does not work.\n\n3. 6 Pack Earbuds Headphone Wired with Microphone\n- Noise isolating in-ear\n- Built-in microphone and volume control\n- Compatible with iPhone, Android, PC\n- Positive: No specific positive review found.\n- Negative: No specific negative review found.\n\n4. KNTARU Earplugs Earphones\n- Wired\n- Noise suppression\n- Waterproof\n- Suitable for work, study, fitness\n- Positive: No specific positive review found.\n- Negative: No specific negative review found.\n\nWaterproof Speakers:\n1. comiso IPX7 Waterproof Bluetooth Speakers\n- IP67 Waterproof and dustproof\n- Portable, compact, floating\n- 20 hours playtime\n- Bluetooth 5.0\n- Positive: No specific positive review found.\n- Negative: No specific negative review found.\n\n2. LENRUE Portable Bluetooth Speakers\n- IPX7 Waterproof\n- 20W stereo sound\n- 20 hours playtime\n- Built-in mic\n- Positive: Great performance, very pleased users.\n- Negative: No specific negative review found.\n\n3. JBL Flip 6\n- IPX7 Waterproof\n- 12 hours playtime\n- Bluetooth 5.1\n- Powerful sound and deep bass\n- Positive: No specific positive review found.\n- Negative: No specific negative review found.\n\n4. BOGASING Bluetooth Speakers M4\n- 40W deep bass\n- IPX7 Waterproof\n- Bluetooth 5.0\n- Built-in mic\n- Positive: Good speaker, users like it.\n- Negative: No specific negative review found.\n\n5. Tronsmart Bang Mini Portable Bluetooth Speaker\n- 50W wireless stereo sound\n- IPX6 Waterproof\n- Bluetooth 5.3\n- Beat-driven light show\n- 15 hours playtime\n- Positive: Good value for the price.\n- Negative: No specific negative review found.\n\nIf you want more detailed reviews or information on any specific item, please let me know!',
#  'available_tools': [{'name': 'get_formatted_context',
#    'description': 'Get the top k context, each representing an inventory item for a given query.',
#    'parameters': {'type': 'object',
#     'properties': {'query': {'type': 'string',
#       'description': 'The query to get the top k context for'},
#      'top_k': {'type': 'integer',
#       'description': 'The number of context chunks to retrieve, works best with 5 or more',
#       'default': 5}}},
#    'required': ['query'],
#    'returns': {'type': 'string',
#     'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}},
#   {'name': 'get_formatted_reviews_context',
#    'description': 'Get the top k reviews matching a query for a list of prefiltered items.',
#    'parameters': {'type': 'object',
#     'properties': {'query': {'type': 'string',
#       'description': 'The query to get the top k reviews for'},
#      'item_list': {'type': 'array',
#       'description': 'The list of item IDs to prefilter for before running the query'},
#      'top_k': {'type': 'integer',
#       'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered',
#       'default': 5}}},
#    'required': ['query', 'item_list'],
#    'returns': {'type': 'string',
#     'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}],
#  'tool_calls': [],
#  'final_answer': True,
#  'references': [RAGUsedContext(id='B0BBFNHMYX', description='aeac Wireless Earbuds'),
#   RAGUsedContext(id='B09PYK37K4', description='100SEASHELL Long Cord Wired Earbuds'),
#   RAGUsedContext(id='B09Y5DZW52', description='6 Pack Earbuds Headphone Wired with Microphone'),
#   RAGUsedContext(id='B0BX2RDHB8', description='KNTARU Earplugs Earphones'),
#   RAGUsedContext(id='B0BXKHLT54', description='comiso IPX7 Waterproof Bluetooth Speakers'),
#   RAGUsedContext(id='B09Y96HMY2', description='LENRUE Portable Bluetooth Speakers'),
#   RAGUsedContext(id='B09ZNKRFSC', description='JBL Flip 6 Waterproof Portable Bluetooth Speaker'),
#   RAGUsedContext(id='B0C999S8YM', description='BOGASING Bluetooth Speakers M4'),
#   RAGUsedContext(id='B0B93MRTWF', description='Tronsmart Bang Mini Portable Bluetooth Speaker'),
#   RAGUsedContext(id='B0BBFNHMYX', description='aeac Wireless Earbuds'),
#   RAGUsedContext(id='B09PYK37K4', description='100SEASHELL Long Cord Wired Earbuds'),
#   RAGUsedContext(id='B09Y5DZW52', description='6 Pack Earbuds Headphone Wired with Microphone'),
#   RAGUsedContext(id='B0BX2RDHB8', description='KNTARU Earplugs Earphones'),
#   RAGUsedContext(id='B0BXKHLT54', description='comiso IPX7 Waterproof Bluetooth Speakers'),
#   RAGUsedContext(id='B09Y96HMY2', description='LENRUE Portable Bluetooth Speakers'),
#   RAGUsedContext(id='B09ZNKRFSC', description='JBL Flip 6'),
#   RAGUsedContext(id='B0C999S8YM', description='BOGASING Bluetooth Speakers M4'),
#   RAGUsedContext(id='B0B93MRTWF', description='Tronsmart Bang Mini Portable Bluetooth Speaker'),
#   RAGUsedContext(id='B0BBFNHMYX', description='aeac Wireless Earbuds'),
#   RAGUsedContext(id='B09PYK37K4', description='100SEASHELL Long Cord Wired Earbuds'),
#   RAGUsedContext(id='B09Y5DZW52', description='6 Pack Earbuds Headphone Wired with Microphone'),
#   RAGUsedContext(id='B0BX2RDHB8', description='KNTARU Earplugs Earphones'),
#   RAGUsedContext(id='B0BXKHLT54', description='comiso IPX7 Waterproof Bluetooth Speakers'),
#   RAGUsedContext(id='B09Y96HMY2', description='LENRUE Portable Bluetooth Speakers'),
#   RAGUsedContext(id='B09ZNKRFSC', description='JBL Flip 6 Waterproof Portable Bluetooth Speaker'),
#   RAGUsedContext(id='B0C999S8YM', description='BOGASING Bluetooth Speakers M4'),
#   RAGUsedContext(id='B0B93MRTWF', description='Tronsmart Bang Mini Portable Bluetooth Speaker')]}

# %%
print(answer_1["answer"])
# Out:
# Here are some earphones and waterproof speakers available along with positive and negative user reviews for each:
#
# Earphones:
# 1. aeac Wireless Earbuds
# - Wireless Bluetooth
# - IPX5 Waterproof
# - Built-in Mic
# - Color: White
# - Positive: No specific positive review found.
# - Negative: Some users reported charging issues and dissatisfaction.
#
# 2. 100SEASHELL Long Cord Wired Earbuds
# - No Microphone
# - Noise isolating
# - Bass blocking
# - 3.5mm stereo headset
# - Compatible with multiple devices
# - Positive: Good product overall, no issues reported.
# - Negative: Left earbud sometimes does not work.
#
# 3. 6 Pack Earbuds Headphone Wired with Microphone
# - Noise isolating in-ear
# - Built-in microphone and volume control
# - Compatible with iPhone, Android, PC
# - Positive: No specific positive review found.
# - Negative: No specific negative review found.
#
# 4. KNTARU Earplugs Earphones
# - Wired
# - Noise suppression
# - Waterproof
# - Suitable for work, study, fitness
# - Positive: No specific positive review found.
# - Negative: No specific negative review found.
#
# Waterproof Speakers:
# 1. comiso IPX7 Waterproof Bluetooth Speakers
# - IP67 Waterproof and dustproof
# - Portable, compact, floating
# - 20 hours playtime
# - Bluetooth 5.0
# - Positive: No specific positive review found.
# - Negative: No specific negative review found.
#
# 2. LENRUE Portable Bluetooth Speakers
# - IPX7 Waterproof
# - 20W stereo sound
# - 20 hours playtime
# - Built-in mic
# - Positive: Great performance, very pleased users.
# - Negative: No specific negative review found.
#
# 3. JBL Flip 6
# - IPX7 Waterproof
# - 12 hours playtime
# - Bluetooth 5.1
# - Powerful sound and deep bass
# - Positive: No specific positive review found.
# - Negative: No specific negative review found.
#
# 4. BOGASING Bluetooth Speakers M4
# - 40W deep bass
# - IPX7 Waterproof
# - Bluetooth 5.0
# - Built-in mic
# - Positive: Good speaker, users like it.
# - Negative: No specific negative review found.
#
# 5. Tronsmart Bang Mini Portable Bluetooth Speaker
# - 50W wireless stereo sound
# - IPX6 Waterproof
# - Bluetooth 5.3
# - Beat-driven light show
# - 15 hours playtime
# - Positive: Good value for the price.
# - Negative: No specific negative review found.
#
# If you want more detailed reviews or information on any specific item, please let me know!

# %%
state = {
    "messages": [{"role": "user", "content": "Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?"}],
    "available_tools": tool_descriptions
}
config = {"configurable": {"thread_id": "test000012"}}

with PostgresSaver.from_conn_string("postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db") as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        state,
        config=config,
        stream_mode="updates"
    ):
        print(chunk)
# Out:
# {'intent_router_node': {'question_relevant': True, 'answer': "Here are some earphones and waterproof speakers available along with their positive and negative user reviews:\n\nEarphones:\n1. aeac Wireless Earbuds - Positive: Great for the price, easy to pair and use. Negative: Some users reported charging issues.\n2. 100SEASHELL Long Cord Wired Earbuds - Positive: Good product overall. Negative: Left earbud sometimes doesn't work.\n3. 6 Pack Earbuds Headphone Wired with Microphone - No specific reviews retrieved.\n4. KNTARU Earplugs Earphones - No specific reviews retrieved.\n\nWaterproof Speakers:\n1. comiso IPX7 Waterproof Bluetooth Speakers - Negative: Bluetooth stopped working after 2 months, poor customer service.\n2. LENRUE Portable Bluetooth Speakers - Positive: Great output, works well. Negative: Not very loud according to some users.\n3. JBL Flip 6 - Positive: Exactly as advertised, excellent product. Negative: Missing charge cord, sound quality concerns.\n4. BOGASING Bluetooth Speakers M4 - Positive: Good product, liked by users.\n5. Tronsmart Bang Mini Portable Bluetooth Speaker - Positive: Good for the price.\n\nIf you want more details or additional options, please let me know!"}}
# {'agent_node': {'messages': [AIMessage(content="Here are some earphones and waterproof speakers available with their positive and negative user reviews:\n\nEarphones:\n1. aeac Wireless Earbuds (ID: B0BBFNHMYX)\n   - Positive: Great for the price, easy to pair and use, recommended by users.\n   - Negative: Some users reported charging issues and expected better quality.\n\n2. 100SEASHELL Long Cord Wired Earbuds (ID: B09PYK37K4)\n   - Positive: Good product overall, excellent sound quality.\n   - Negative: Some reported the left earbud not working and connectivity issues with TV.\n\n3. 6 Pack Earbuds Headphone Wired with Microphone (ID: B09Y5DZW52)\n   - No specific reviews retrieved.\n\n4. KNTARU Earplugs Earphones (ID: B0BX2RDHB8)\n   - No specific reviews retrieved.\n\nWaterproof Speakers:\n1. comiso IPX7 Waterproof Bluetooth Speakers (ID: B0BXKHLT54)\n   - Negative: Bluetooth stopped working after 2 months, doesn't hold charge, poor customer service.\n\n2. LENRUE Portable Bluetooth Speakers (ID: B09Y96HMY2)\n   - Positive: Great output, works well, very happy with the speaker.\n   - Negative: Sound not very loud, considered junk by some users.\n\n3. JBL Flip 6 (ID: B09ZNKRFSC)\n   - Positive: Exactly as advertised, excellent product.\n   - Negative: Missing charge cord, sound quality not as expected by some.\n\n4. BOGASING Bluetooth Speakers M4 (ID: B0C999S8YM)\n   - Positive: Good product, liked by users.\n   - Negative: No negative reviews retrieved.\n\n5. Tronsmart Bang Mini Portable Bluetooth Speaker (ID: B0B93MRTWF)\n   - Positive: Good for the price.\n   - Negative: No negative reviews retrieved.\n\nIf you want detailed specifications or more reviews for any specific item, please let me know!", additional_kwargs={}, response_metadata={})], 'tool_calls': [], 'iteration': 4, 'answer': "Here are some earphones and waterproof speakers available with their positive and negative user reviews:\n\nEarphones:\n1. aeac Wireless Earbuds (ID: B0BBFNHMYX)\n   - Positive: Great for the price, easy to pair and use, recommended by users.\n   - Negative: Some users reported charging issues and expected better quality.\n\n2. 100SEASHELL Long Cord Wired Earbuds (ID: B09PYK37K4)\n   - Positive: Good product overall, excellent sound quality.\n   - Negative: Some reported the left earbud not working and connectivity issues with TV.\n\n3. 6 Pack Earbuds Headphone Wired with Microphone (ID: B09Y5DZW52)\n   - No specific reviews retrieved.\n\n4. KNTARU Earplugs Earphones (ID: B0BX2RDHB8)\n   - No specific reviews retrieved.\n\nWaterproof Speakers:\n1. comiso IPX7 Waterproof Bluetooth Speakers (ID: B0BXKHLT54)\n   - Negative: Bluetooth stopped working after 2 months, doesn't hold charge, poor customer service.\n\n2. LENRUE Portable Bluetooth Speakers (ID: B09Y96HMY2)\n   - Positive: Great output, works well, very happy with the speaker.\n   - Negative: Sound not very loud, considered junk by some users.\n\n3. JBL Flip 6 (ID: B09ZNKRFSC)\n   - Positive: Exactly as advertised, excellent product.\n   - Negative: Missing charge cord, sound quality not as expected by some.\n\n4. BOGASING Bluetooth Speakers M4 (ID: B0C999S8YM)\n   - Positive: Good product, liked by users.\n   - Negative: No negative reviews retrieved.\n\n5. Tronsmart Bang Mini Portable Bluetooth Speaker (ID: B0B93MRTWF)\n   - Positive: Good for the price.\n   - Negative: No negative reviews retrieved.\n\nIf you want detailed specifications or more reviews for any specific item, please let me know!", 'final_answer': True, 'references': [RAGUsedContext(id='B0BBFNHMYX', description='aeac Wireless Earbuds'), RAGUsedContext(id='B09PYK37K4', description='100SEASHELL Long Cord Wired Earbuds'), RAGUsedContext(id='B09Y5DZW52', description='6 Pack Earbuds Headphone Wired with Microphone'), RAGUsedContext(id='B0BX2RDHB8', description='KNTARU Earplugs Earphones'), RAGUsedContext(id='B0BXKHLT54', description='comiso IPX7 Waterproof Bluetooth Speakers'), RAGUsedContext(id='B09Y96HMY2', description ...

# %%
state = {
    "messages": [{"role": "user", "content": "Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?"}],
    "available_tools": tool_descriptions
}
config = {"configurable": {"thread_id": "test000014"}}

with PostgresSaver.from_conn_string("postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db") as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        state,
        config=config,
        stream_mode=["debug", "updates"]
    ):
        print(chunk)
# Out:
# ('debug', {'step': -1, 'timestamp': '2025-11-23T14:10:32.949250+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test000014', 'checkpoint_id': '1f0c8762-ca8c-6f02-bfff-a8cdff0ccc95'}}, 'parent_config': None, 'values': {'messages': [], 'references': []}, 'metadata': {'source': 'input', 'step': -1, 'parents': {}}, 'next': ['__start__'], 'tasks': [{'id': 'ad812e11-59ad-25ab-f61d-acf21519b4f8', 'name': '__start__', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 0, 'timestamp': '2025-11-23T14:10:32.957601+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test000014', 'checkpoint_id': '1f0c8762-ca9c-6cae-8000-77510e0de514'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test000014', 'checkpoint_id': '1f0c8762-ca8c-6f02-bfff-a8cdff0ccc95'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?'}], 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], 'references': []}, 'metadata': {'source': 'loop', 'step': 0, 'parents': {}}, 'next': ['intent_router_node'], 'tasks': [{'id': '379be552-1619-6a11-8ca0-1f9719c377b3', 'name': 'intent_router_node', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 1, 'timestamp': '2025-11-23T14:10:32.957676+00:00', 'type': 'task', 'payload': {'id': '379be552-1619-6a11-8ca0-1f9719c377b3', 'name': 'intent_router_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?'}], question_relevant=False, iteration=0, answer='', available_tools=[{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], tool_calls=[], final_answer=False, references=[]), 'triggers': ('branch:to:intent_router_node',)}})
# ('updates', {'intent_router_node': {'question_relevant': True, 'answer': ''}})
# ('debug', {'step': 1, 'timestamp': '2025-11-23T14:10:34.686523+00:00', 'type': 'task_result', 'payload': {'id': '379be552-1619-6a11-8ca0-1f9719c377b3', 'name': 'intent_router_node', 'error': None, 'result': {'question_relevant': True, 'answer': ''}, 'interrupts': []}})
# ('debug', {'step': 1, 'timestamp': '2025-11-23T14:10:34.686915+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test000014', 'checkpoint_id': '1f0c8762-db2a-6e4a-8001-8c96eb595864'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test000014', 'checkpoint_id': '1f0c8762-ca9c-6cae-8000-77510e0de514'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?'}], 'question_relevant': True, 'answer': '', 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], 'references': []}, 'metadata': {'source': 'loop', 'step': 1, 'parents': {}}, 'next': ['agent_node'], 'tasks': [{'id': '5cf95a8f-bd4a-7e9e-a889-904027b2421e', 'name': 'agent_node', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 2, 'timestamp': '2025-11-23T14:10:34.686929+00:00', 'type': 'task', 'payload': {'id': '5cf95a8f-bd4a-7e9e-a889-904027b2421e', 'name': 'agent_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?'}], question_relevant=True, iteration=0, answer='', available_tools=[{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], tool_calls=[], final_answer=False, references=[]), 'triggers': ('branch:to:agent_node',)}})
# ('updates', {'agent_node': {'messages': [AIMessage(content='I will find earphones and waterproof speakers for you and also get positive and negative user reviews for each item suggested.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'waterproof speakers', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}])], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'waterproof speakers', 'top_k': 5})], 'iteration': 1, 'answer': 'I will find earphones and waterproof speakers for you and also get positive and negative user reviews for each item suggested.', 'final_answer': False, 'references': []}})
# ('debug', {'step': 2, 'timestamp': '2025-11-23T14:10:38.119699+00:00', 'type': 'task_result', 'payload': {'id': '5cf95a8f-bd4a-7e9e-a889-904027b2421e', 'name': 'agent_node', 'error': None, 'result': {'messages': [AIMessage(content='I will find earphones and waterproof speakers for you and also get positive and negative user reviews for each item suggested.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'waterproof speakers', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}])], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'waterproof speakers', 'top_k': 5})], 'iteration': 1, 'answer': 'I will find earphones and waterproof speakers for you and also get positive and negative user reviews for each item suggested.', 'final_answer': False, 'references': []}, 'interrupts': []}})
# ('debug', {'step': 2, 'timestamp': '2025-11-23T14:10:38.120183+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test000014', 'checkpoint_id': '1f0c8762-fbe8-6a92-8002-26d8eb5f60cd'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test000014', 'checkpoint_id': '1f0c8762-db2a-6e4a-8001-8c96eb595864'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?'}, AIMessage(content='I will find earphones and waterproof speakers for you and also get positive and negative user reviews for each item suggested.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'waterproof speakers', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}])], 'question_relevant': True, 'iteration': 1, 'answer': 'I will find earphones and waterproof speakers for you and also get positive and negative user reviews for each item suggested.', 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'waterproof speakers', 'top_k': 5})], 'final_answer': False, 'references': []}, 'metadata': {'source': 'loop', 'step': 2, 'parents': {}}, 'next': ['tool_node'], 'tasks': [{'id': 'bfdc9155-390b-6f35-2661-6d8894898a04', 'name': 'tool_node', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 3, 'timestamp': '2025-11-23T14:10:38.120199+00:00', 'type': 'task', 'payload': {'id': 'bfdc9155-390b-6f35-2661-6d8894898a04', 'name': 'tool_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?'}, AIMessage(content='I will find earphones and waterproof speakers for you and also get positive and negative user reviews for each item suggested.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'waterproof speakers', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}])], question_relevant=True, iteration=1, answer='I will find earphones and waterproof speakers for you and also get positive and negative user reviews for each item suggested.', available_tools=[{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], tool_calls=[ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'waterproof speakers', 'top_k': 5})], final_answer=False, references=[]), 'triggers': ('branch:to:tool_node',)}})
# ('updates', {'tool_node': {'messages': [ToolMessage(content="- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super comfortable the ergonomic in-ear design can maintain a firm fit every time, ensuring proper fit and extra comfort. High-fidelity sound quality-earbud headphones provide clear top-level sound quality in the recording studio, with strong bass, strong midrange, and precise treble response, A9 can bring you delightful music. Wide compatibility-very is suitable for iPhone devices, Android smartphones, iPods, iPads, MP3 players, music speakers, and all other interface devices with 3.5mm headphone jack. High-quality service-If you have any questions, please feel free to contact us, we will reply in time. We hope you enjoy a pleasant shopping experience.\n- ID: B0BX2RDHB8, rating: 4.0, description: KNTARU Earplugs Earphones，Earphones That Look Like earplugs，Earphones Disguised as earplugs，Noise Suppression，Hearing Protection，Waterproof，for Work，Study，Fitness，Noisy Places【INCLUDES】 NRR value: 28dB ,Color: blue + orange, Connection: wired headphone ...
# ('debug', {'step': 3, 'timestamp': '2025-11-23T14:10:40.442218+00:00', 'type': 'task_result', 'payload': {'id': 'bfdc9155-390b-6f35-2661-6d8894898a04', 'name': 'tool_node', 'error': None, 'result': {'messages': [ToolMessage(content="- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super comfortable the ergonomic in-ear design can maintain a firm fit every time, ensuring proper fit and extra comfort. High-fidelity sound quality-earbud headphones provide clear top-level sound quality in the recording studio, with strong bass, strong midrange, and precise treble response, A9 can bring you delightful music. Wide compatibility-very is suitable for iPhone devices, Android smartphones, iPods, iPads, MP3 players, music speakers, and all other interface devices with 3.5mm headphone jack. High-quality service-If you have any questions, please feel free to contact us, we will reply in time. We hope you enjoy a pleasant shopping experience.\n- ID: B0BX2RDHB8, rating: 4.0, description: KNTARU Earplugs Earphones，Earphones That Look Like earplugs，Earphones Disguised  ...
# ('debug', {'step': 3, 'timestamp': '2025-11-23T14:10:40.442448+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test000014', 'checkpoint_id': '1f0c8763-120e-6d1c-8003-bede02b2486c'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test000014', 'checkpoint_id': '1f0c8762-fbe8-6a92-8002-26d8eb5f60cd'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?'}, AIMessage(content='I will find earphones and waterproof speakers for you and also get positive and negative user reviews for each item suggested.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'waterproof speakers', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, provi ...
# ('debug', {'step': 4, 'timestamp': '2025-11-23T14:10:40.442453+00:00', 'type': 'task', 'payload': {'id': 'f08c6a8d-d4a6-04e9-b0fd-8197045b308d', 'name': 'agent_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?'}, AIMessage(content='I will find earphones and waterproof speakers for you and also get positive and negative user reviews for each item suggested.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'waterproof speakers', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super comfortable the ergonomic in-ear design can maintain a firm fit every time, ensuring proper fit and extra comfort. High-fidelity sound quality-earbud headphones provide clear top- ...
# ('updates', {'agent_node': {'messages': [AIMessage(content='For earphones, here are some options:\n1. aeac Wireless Earbuds - Wireless Bluetooth earbuds with IPX5 waterproof rating and built-in mic.\n2. 100SEASHELL Long Cord Wired Earbuds - Wired earbuds with noise isolating blocking bass, no microphone.\n3. 6 Pack Earbuds Headphone Wired with Microphone - Wired earbuds with noise isolation, built-in microphone, and volume control.\n4. KNTARU Earplugs Earphones - Wired earphones disguised as earplugs with noise suppression and waterproof features.\n\nFor waterproof speakers, here are some options:\n1. comiso IPX7 Waterproof Bluetooth Speakers - Portable wireless speaker with rich bass, HD sound, 20H playtime, and IP67 waterproof and dustproof rating.\n2. LENRUE Portable Bluetooth Speakers - IPX7 waterproof wireless speaker with 20W stereo sound, rich bass, 20H playtime, and built-in mic.\n3. JBL Flip 6 - Waterproof portable Bluetooth speaker with powerful sound, deep bass, IPX7 waterproof rating, and 12 hours of playtime.\n4. BOGASING Bluetooth Speakers, M4 Portable Wireless Speaker - 40W deep bass, IPX7 waterproof, Bluetooth 5.0, built-in mic, and TWS.\n5. Tronsmart Bang Mini Portable Bluetooth Speaker - 50W wireless stereo sound, IPX6 waterproof, Bluetooth 5.3, LED light show, and power bank function.\n\nI will now fetch positive and negative user reviews for these items.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_reviews_context', 'args': {'item_list': ['B0BBFNHMYX', 'B09PYK37K4', 'B09Y5DZW52', 'B0BX2RDHB8'], 'query': 'positive', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_reviews_context', 'args': {'item_list': ['B0BBFNHMYX', 'B09PYK37K4', 'B09Y5DZW52', 'B0BX2RDHB8'], 'query': 'negative', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_reviews_context', 'args': {'item_list': ['B0BXKHLT54', 'B09Y96HMY2', 'B09ZNKRFSC', 'B0C999S8YM', 'B0B93MRTWF'], 'query': 'positive', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}, {'name': 'get_formatted_reviews_context', 'args': {'item_list': ['B0BXKHLT54', 'B09Y96HMY2', 'B09ZNKRFSC', 'B0C999S8YM', 'B0B93MRTWF'], 'query': 'negative', 'top_k': 5}, 'id': 'call_3', 'type': 'tool_call'}])], 'tool_calls': [ToolCall(name='get_formatted_reviews_context', arguments={'item_list': ['B0BBFNHMYX', 'B09PYK37K4', 'B09Y5DZW52', 'B0BX2RDHB8'], 'query': 'positive', 'top_k': 5}), ToolCall(name='get_formatted_reviews_context', arguments={'item_list': ['B0BBFNHMYX', 'B09PYK37K4', 'B09Y5DZW52', 'B0BX2RDHB8'], 'query': 'negative', 'top_k': 5}), ToolCall(name='get_formatted_reviews_context', arguments={'item_list': ['B0BXKHLT54', 'B09Y96HMY2', 'B09ZNKRFSC', 'B0C999S8YM', 'B0B93MRTWF'], 'query': 'positive', 'top_k': 5}), ToolCall(name='get_formatted_reviews_context', arguments={'item_list': ['B0BXKHLT54', 'B09Y96HMY2', 'B09ZNKRFSC', 'B0C999S8YM', 'B0B93MRTWF'], 'query': 'negative', 'top_k': 5})], 'iteration': 2, 'answer': 'For earphones, here are some options:\n1. aeac Wireless Earbuds - Wireless Bluetooth earbuds with IPX5 waterproof rating and built-in mic.\n2. 100SEASHELL Long Cord Wired Earbuds - Wired earbuds with noise isolating blocking bass, no microphone.\n3. 6 Pack Earbuds Headphone Wired with Microphone - Wired earbuds with noise isolation, built-in microphone, and volume control.\n4. KNTARU Earplugs Earphones - Wired earphones disguised as earplugs with noise suppression and waterproof features.\n\nFor waterproof speakers, here are some options:\n1. comiso IPX7 Waterproof Bluetooth Speakers - Portable wireless speaker with rich bass, HD sound, 20H playtime, and IP67 waterproof and dustproof rating.\n2. LENRUE Portable Bluetooth Speakers - IPX7 waterproof wireless speaker with 20W stereo sound, rich bass, 20H playtime, and built-in mic.\n3. JBL Flip 6 - Waterproof portable Bluetooth speaker with powerful sound, deep bass, IPX7 waterproof rating, and 12 hours of playtime.\n4. BOGASING Bluetooth Speakers,  ...
# ('debug', {'step': 4, 'timestamp': '2025-11-23T14:10:53.978688+00:00', 'type': 'task_result', 'payload': {'id': 'f08c6a8d-d4a6-04e9-b0fd-8197045b308d', 'name': 'agent_node', 'error': None, 'result': {'messages': [AIMessage(content='For earphones, here are some options:\n1. aeac Wireless Earbuds - Wireless Bluetooth earbuds with IPX5 waterproof rating and built-in mic.\n2. 100SEASHELL Long Cord Wired Earbuds - Wired earbuds with noise isolating blocking bass, no microphone.\n3. 6 Pack Earbuds Headphone Wired with Microphone - Wired earbuds with noise isolation, built-in microphone, and volume control.\n4. KNTARU Earplugs Earphones - Wired earphones disguised as earplugs with noise suppression and waterproof features.\n\nFor waterproof speakers, here are some options:\n1. comiso IPX7 Waterproof Bluetooth Speakers - Portable wireless speaker with rich bass, HD sound, 20H playtime, and IP67 waterproof and dustproof rating.\n2. LENRUE Portable Bluetooth Speakers - IPX7 waterproof wireless speaker with 20W stereo sound, rich bass, 20H playtime, and built-in mic.\n3. JBL Flip 6 - Waterproof portable Bluetooth speaker with powerful sound, deep bass, IPX7 waterproof rating, and 12 hours of playtime.\n4. BOGASING Bluetooth Speakers, M4 Portable Wireless Speaker - 40W deep bass, IPX7 waterproof, Bluetooth 5.0, built-in mic, and TWS.\n5. Tronsmart Bang Mini Portable Bluetooth Speaker - 50W wireless stereo sound, IPX6 waterproof, Bluetooth 5.3, LED light show, and power bank function.\n\nI will now fetch positive and negative user reviews for these items.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_reviews_context', 'args': {'item_list': ['B0BBFNHMYX', 'B09PYK37K4', 'B09Y5DZW52', 'B0BX2RDHB8'], 'query': 'positive', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_reviews_context', 'args': {'item_list': ['B0BBFNHMYX', 'B09PYK37K4', 'B09Y5DZW52', 'B0BX2RDHB8'], 'query': 'negative', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_reviews_context', 'args': {'item_list': ['B0BXKHLT54', 'B09Y96HMY2', 'B09ZNKRFSC', 'B0C999S8YM', 'B0B93MRTWF'], 'query': 'positive', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}, {'name': 'get_formatted_reviews_context', 'args': {'item_list': ['B0BXKHLT54', 'B09Y96HMY2', 'B09ZNKRFSC', 'B0C999S8YM', 'B0B93MRTWF'], 'query': 'negative', 'top_k': 5}, 'id': 'call_3', 'type': 'tool_call'}])], 'tool_calls': [ToolCall(name='get_formatted_reviews_context', arguments={'item_list': ['B0BBFNHMYX', 'B09PYK37K4', 'B09Y5DZW52', 'B0BX2RDHB8'], 'query': 'positive', 'top_k': 5}), ToolCall(name='get_formatted_reviews_context', arguments={'item_list': ['B0BBFNHMYX', 'B09PYK37K4', 'B09Y5DZW52', 'B0BX2RDHB8'], 'query': 'negative', 'top_k': 5}), ToolCall(name='get_formatted_reviews_context', arguments={'item_list': ['B0BXKHLT54', 'B09Y96HMY2', 'B09ZNKRFSC', 'B0C999S8YM', 'B0B93MRTWF'], 'query': 'positive', 'top_k': 5}), ToolCall(name='get_formatted_reviews_context', arguments={'item_list': ['B0BXKHLT54', 'B09Y96HMY2', 'B09ZNKRFSC', 'B0C999S8YM', 'B0B93MRTWF'], 'query': 'negative', 'top_k': 5})], 'iteration': 2, 'answer': 'For earphones, here are some options:\n1. aeac Wireless Earbuds - Wireless Bluetooth earbuds with IPX5 waterproof rating and built-in mic.\n2. 100SEASHELL Long Cord Wired Earbuds - Wired earbuds with noise isolating blocking bass, no microphone.\n3. 6 Pack Earbuds Headphone Wired with Microphone - Wired earbuds with noise isolation, built-in microphone, and volume control.\n4. KNTARU Earplugs Earphones - Wired earphones disguised as earplugs with noise suppression and waterproof features.\n\nFor waterproof speakers, here are some options:\n1. comiso IPX7 Waterproof Bluetooth Speakers - Portable wireless speaker with rich bass, HD sound, 20H playtime, and IP67 waterproof and dustproof rating.\n2. LENRUE Portable Bluetooth Speakers - IPX7 waterproof wireless speaker with 20W stereo sound, rich bass, 20H playtime, and built-in mic ...
# ('debug', {'step': 4, 'timestamp': '2025-11-23T14:10:53.979036+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test000014', 'checkpoint_id': '1f0c8763-9326-6e90-8004-3e6290600681'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test000014', 'checkpoint_id': '1f0c8763-120e-6d1c-8003-bede02b2486c'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?'}, AIMessage(content='I will find earphones and waterproof speakers for you and also get positive and negative user reviews for each item suggested.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'waterproof speakers', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, provi ...
# ...
# ('updates', {'agent_node': {'messages': [AIMessage(content="Here are some earphones and waterproof speakers along with their positive and negative user reviews:\n\nEarphones:\n1. aeac Wireless Earbuds (IPX5 Waterproof, Built-in Mic)\n   - Positive: Great for the price, easy to pair and use, works as intended.\n   - Negative: Some units didn't charge properly, left earbud not working for some users.\n\n2. 100SEASHELL Long Cord Wired Earbuds (No Microphone)\n   - Positive: Good product overall, no issues reported.\n   - Negative: Some users reported connection issues with TV, left earbud not working.\n\n3. 6 Pack Earbuds Headphone Wired with Microphone\n   - No specific reviews retrieved.\n\n4. KNTARU Earplugs Earphones (Waterproof, Noise Suppression)\n   - No specific reviews retrieved.\n\nWaterproof Speakers:\n1. comiso IPX7 Waterproof Bluetooth Speakers\n   - No specific reviews retrieved.\n\n2. LENRUE Portable Bluetooth Speakers (IPX7 Waterproof, 20W Stereo Sound)\n   - Positive: Great output, works well, very pleased.\n   - Negative: Some users found the sound not very loud.\n\n3. JBL Flip 6 (IPX7 Waterproof, 12 Hours Playtime)\n   - Positive: Exactly as advertised, excellent product.\n   - Negative: Missing charging cord in some packages, sound quality not as loud as expected.\n\n4. BOGASING Bluetooth Speakers, M4 Portable Wireless Speaker (IPX7 Waterproof, 40W Deep Bass)\n   - Positive: Good for the price, liked by users.\n   - Negative: No significant negative reviews found.\n\n5. Tronsmart Bang Mini Portable Bluetooth Speaker (IPX6 Waterproof, 50W Sound)\n   - Positive: Good for the price.\n   - Negative: Some units stopped working after a couple of months, poor customer service reported.\n\nPlease let me know if you want detailed specifications for any of these items.\n", additional_kwargs={}, response_metadata={})], 'tool_calls': [], 'iteration': 3, 'answer': "Here are some earphones and waterproof speakers along with their positive and negative user reviews:\n\nEarphones:\n1. aeac Wireless Earbuds (IPX5 Waterproof, Built-in Mic)\n   - Positive: Great for the price, easy to pair and use, works as intended.\n   - Negative: Some units didn't charge properly, left earbud not working for some users.\n\n2. 100SEASHELL Long Cord Wired Earbuds (No Microphone)\n   - Positive: Good product overall, no issues reported.\n   - Negative: Some users reported connection issues with TV, left earbud not working.\n\n3. 6 Pack Earbuds Headphone Wired with Microphone\n   - No specific reviews retrieved.\n\n4. KNTARU Earplugs Earphones (Waterproof, Noise Suppression)\n   - No specific reviews retrieved.\n\nWaterproof Speakers:\n1. comiso IPX7 Waterproof Bluetooth Speakers\n   - No specific reviews retrieved.\n\n2. LENRUE Portable Bluetooth Speakers (IPX7 Waterproof, 20W Stereo Sound)\n   - Positive: Great output, works well, very pleased.\n   - Negative: Some users found the sound not very loud.\n\n3. JBL Flip 6 (IPX7 Waterproof, 12 Hours Playtime)\n   - Positive: Exactly as advertised, excellent product.\n   - Negative: Missing charging cord in some packages, sound quality not as loud as expected.\n\n4. BOGASING Bluetooth Speakers, M4 Portable Wireless Speaker (IPX7 Waterproof, 40W Deep Bass)\n   - Positive: Good for the price, liked by users.\n   - Negative: No significant negative reviews found.\n\n5. Tronsmart Bang Mini Portable Bluetooth Speaker (IPX6 Waterproof, 50W Sound)\n   - Positive: Good for the price.\n   - Negative: Some units stopped working after a couple of months, poor customer service reported.\n\nPlease let me know if you want detailed specifications for any of these items.\n", 'final_answer': True, 'references': [RAGUsedContext(id='B0BBFNHMYX', description='aeac Wireless Earbuds'), RAGUsedContext(id='B09PYK37K4', description='100SEASHELL Long Cord Wired Earbuds'), RAGUsedContext(id='B09Y5DZW52', description='6 Pack Earbuds Headphone Wired with Microphone'), RAGUsedContext(id='B0BX2RDHB8', description='KNTARU Earplugs  ...
# ('debug', {'step': 6, 'timestamp': '2025-11-23T14:11:04.717485+00:00', 'type': 'task_result', 'payload': {'id': '9606e383-4e9f-7805-5471-b34b3096f848', 'name': 'agent_node', 'error': None, 'result': {'messages': [AIMessage(content="Here are some earphones and waterproof speakers along with their positive and negative user reviews:\n\nEarphones:\n1. aeac Wireless Earbuds (IPX5 Waterproof, Built-in Mic)\n   - Positive: Great for the price, easy to pair and use, works as intended.\n   - Negative: Some units didn't charge properly, left earbud not working for some users.\n\n2. 100SEASHELL Long Cord Wired Earbuds (No Microphone)\n   - Positive: Good product overall, no issues reported.\n   - Negative: Some users reported connection issues with TV, left earbud not working.\n\n3. 6 Pack Earbuds Headphone Wired with Microphone\n   - No specific reviews retrieved.\n\n4. KNTARU Earplugs Earphones (Waterproof, Noise Suppression)\n   - No specific reviews retrieved.\n\nWaterproof Speakers:\n1. comiso IPX7 Waterproof Bluetooth Speakers\n   - No specific reviews retrieved.\n\n2. LENRUE Portable Bluetooth Speakers (IPX7 Waterproof, 20W Stereo Sound)\n   - Positive: Great output, works well, very pleased.\n   - Negative: Some users found the sound not very loud.\n\n3. JBL Flip 6 (IPX7 Waterproof, 12 Hours Playtime)\n   - Positive: Exactly as advertised, excellent product.\n   - Negative: Missing charging cord in some packages, sound quality not as loud as expected.\n\n4. BOGASING Bluetooth Speakers, M4 Portable Wireless Speaker (IPX7 Waterproof, 40W Deep Bass)\n   - Positive: Good for the price, liked by users.\n   - Negative: No significant negative reviews found.\n\n5. Tronsmart Bang Mini Portable Bluetooth Speaker (IPX6 Waterproof, 50W Sound)\n   - Positive: Good for the price.\n   - Negative: Some units stopped working after a couple of months, poor customer service reported.\n\nPlease let me know if you want detailed specifications for any of these items.\n", additional_kwargs={}, response_metadata={})], 'tool_calls': [], 'iteration': 3, 'answer': "Here are some earphones and waterproof speakers along with their positive and negative user reviews:\n\nEarphones:\n1. aeac Wireless Earbuds (IPX5 Waterproof, Built-in Mic)\n   - Positive: Great for the price, easy to pair and use, works as intended.\n   - Negative: Some units didn't charge properly, left earbud not working for some users.\n\n2. 100SEASHELL Long Cord Wired Earbuds (No Microphone)\n   - Positive: Good product overall, no issues reported.\n   - Negative: Some users reported connection issues with TV, left earbud not working.\n\n3. 6 Pack Earbuds Headphone Wired with Microphone\n   - No specific reviews retrieved.\n\n4. KNTARU Earplugs Earphones (Waterproof, Noise Suppression)\n   - No specific reviews retrieved.\n\nWaterproof Speakers:\n1. comiso IPX7 Waterproof Bluetooth Speakers\n   - No specific reviews retrieved.\n\n2. LENRUE Portable Bluetooth Speakers (IPX7 Waterproof, 20W Stereo Sound)\n   - Positive: Great output, works well, very pleased.\n   - Negative: Some users found the sound not very loud.\n\n3. JBL Flip 6 (IPX7 Waterproof, 12 Hours Playtime)\n   - Positive: Exactly as advertised, excellent product.\n   - Negative: Missing charging cord in some packages, sound quality not as loud as expected.\n\n4. BOGASING Bluetooth Speakers, M4 Portable Wireless Speaker (IPX7 Waterproof, 40W Deep Bass)\n   - Positive: Good for the price, liked by users.\n   - Negative: No significant negative reviews found.\n\n5. Tronsmart Bang Mini Portable Bluetooth Speaker (IPX6 Waterproof, 50W Sound)\n   - Positive: Good for the price.\n   - Negative: Some units stopped working after a couple of months, poor customer service reported.\n\nPlease let me know if you want detailed specifications for any of these items.\n", 'final_answer': True, 'references': [RAGUsedContext(id='B0BBFNHMYX', description='aeac Wireless Earbuds'), RAGUsedContext(id='B09PYK37K4', description='100SEASHELL Long Cord W ...
# ('debug', {'step': 6, 'timestamp': '2025-11-23T14:11:04.717608+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test000014', 'checkpoint_id': '1f0c8763-f990-6910-8006-1eafe09c9170'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test000014', 'checkpoint_id': '1f0c8763-9a6d-6bc2-8005-56471e8ac71e'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?'}, AIMessage(content='I will find earphones and waterproof speakers for you and also get positive and negative user reviews for each item suggested.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'waterproof speakers', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, provi ...

# %%
def process_graph_event(chunk):

    def _is_node_start(chunk):
        return chunk[1].get("type") == "task"

    def _is_node_end(chunk):
        return chunk[0] == "updates"

    def _tool_to_text(tool_call):
        if tool_call.name == "get_formatted_context":
            return f"Looking for items: {tool_call.arguments.get('query', '')}."
        elif tool_call.name == "get_formatted_reviews_context":
            return f"Fetching user reviews..."

    if _is_node_start(chunk):
        if chunk[1].get("payload", {}).get("name") == "intent_router_node":
            print("Analysing the question...")
        if chunk[1].get("payload", {}).get("name") == "agent_node":
            print("Planning...")
        if chunk[1].get("payload", {}).get("name") == "tool_node":
            message = " ".join([_tool_to_text(tool_call) for tool_call in chunk[1].get('payload', {}).get('input', {}).tool_calls])
            print(message)

# %%
state = {
    "messages": [{"role": "user", "content": "Can I get some earphones and waterproof speakers? Could you also give me positive and negative user reviews for each of the items suggested?"}],
    "available_tools": tool_descriptions
}
config = {"configurable": {"thread_id": "test000014"}}

with PostgresSaver.from_conn_string("postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db") as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        state,
        config=config,
        stream_mode=["debug", "updates"]
    ):
        process_graph_event(chunk)
# Out:
# Analysing the question...
# Planning...
