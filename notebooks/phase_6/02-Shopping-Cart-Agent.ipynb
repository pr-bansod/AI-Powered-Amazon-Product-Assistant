# %% [markdown]
# ### Import Dependancies

# %%
from pydantic import BaseModel, Field

from qdrant_client import QdrantClient
from qdrant_client.models import Prefetch, Filter, FieldCondition, MatchAny, FusionQuery, Document


from langsmith import traceable, get_current_run_tree

from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode
from langgraph.types import Send, Command

from langchain_core.messages import AIMessage, ToolMessage, convert_to_openai_messages

from jinja2 import Template
from typing import Literal, Dict, Any, Annotated, List, Optional, Sequence
from IPython.display import Image, display
from operator import add
from openai import OpenAI

import instructor


from utils.utils import get_tool_descriptions, format_ai_message
from utils.tools import get_shopping_cart, add_to_shopping_cart, remove_from_cart, get_formatted_item_context, get_formatted_reviews_context

from langgraph.checkpoint.postgres import PostgresSaver

# %% [markdown]
# ### State and Pydantic Models for structured outputs

# %%
class ToolCall(BaseModel):
    name: str
    arguments: dict

class RAGUsedContext(BaseModel):
    id: str = Field(description="ID of the item used to answer the question.")
    description: str = Field(description="Short description of the item used to answer the question.")

class ProductQAAgentResponse(BaseModel):
    answer: str = Field(description="Answer to the question.")
    references: list[RAGUsedContext] = Field(description="List of items used to answer the question.")
    final_answer: bool = False
    tool_calls: List[ToolCall] = []

# %%
@traceable(
    name="product_qa_agent",
    run_type="llm",
    metadata={"ls_provider": "openai", "ls_model_name": "gpt-4.1-mini"}
)
def product_qa_agent(state) -> dict:

   prompt_template =  """You are a shopping assistant that can answer questions about the products in stock.

You will be given a conversation history and a list of tools you can use to answer the latest query.

<Available tools>
{{ available_tools | tojson }}
</Available tools>

When making tool calls, use this exact format:
{
    "name": "tool_name",
    "arguments": {
        "parameter1": "value1",
        "parameter2": "value2",
    }
}

CRITICAL: All parameters must go inside the "arguments" object, not at the top level of the tool call.

Examples:
- Get formatted item context:
{
    "name": "get_formatted_item_context",
    "arguments": {
        "query": "Kool kids toys.",
        "top_k": 5
    }
}

- Get formatted user reviews:
    {
        "name": "get_formatted_reviews_context",
        "arguments": {
            "query": "Durable.",
            "item_list": ["123", "456"],
            "top_k": 5
        }
    }

CRITICAL RULES:
- If tool_calls has values, final_answer MUST be false
(You cannot call tools and exit the graph in the same response)
- If final_answer is true, tool_calls MUST be []
(You must wait for tool results before exiting the graph)
- If you need tool results before answering, set:
tool_calls=[...], final_answer=false
- After receiving tool results, you can then set:
tool_calls=[], final_answer=true
- When suggesting tool calls, use names specificly provided in the available tools. Don't add any additional text to the names. You can only use get_formatted_item_context or get_formatted_reviews_context for tool names.

Instructions:
- You need to answer the question based on the outputs from the tools using the available tools only.
- Do not suggest the same tool call more than once.
- If the question can be decomposed into multiple sub-questions, suggest all of them.
- If multipple tool calls can be used at once to answer the question, suggest all of them.
- Do not explain your next steps in the answer, instead use tools to answer the question.
- Never use word context and refer to it as the available products.
- If using reviews data, make sure to match reviews to item IDs and summarise them instead of returning them as is, clearly split reviews from general item specification.
- You should only answer questions about the products in stock. If the question is not about the products in stock, you should ask for clarification.
- As an output you need to return the following:

* answer: The answer to the question based on your current knowledge and the tool results.
* references: The list of the indexes from the chunks returned from all tool calls that were used to answer the question. If more than one chunk was used to compile the answer from a single tool call, be sure to return all of them.
* Each reference should have an id and a short description of the item based on the retrieved context.
* final_answer: True if you have all the information needed to provide a complete answer, False otherwise.

- The answer to the question should contain detailed information about the product and should be returned with detailed specification in bullet points.
- The short description should have the name of the item.
- If the user's request requires using a tool, set tool_calls with the appropriate function names and arguments.
"""

   template = Template(prompt_template)
   
   prompt = template.render(
      available_tools=state.product_qa_agent.available_tools
   )

   messages = state.messages

   conversation = []

   for message in messages:
        conversation.append(convert_to_openai_messages(message))

   client = instructor.from_openai(OpenAI())

   response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        response_model=ProductQAAgentResponse,
        messages=[{"role": "system", "content": prompt}, *conversation],
        temperature=0,
   )

   ai_message = format_ai_message(response)

   return {
      "messages": [ai_message],
      "product_qa_agent": {
        "iteration": state.product_qa_agent.iteration + 1,
        "final_answer": response.final_answer,
        "tool_calls": [tool_call.model_dump() for tool_call in response.tool_calls],
        "available_tools": state.product_qa_agent.available_tools
      },
      "answer": response.answer,
      "references": response.references
   }

# %% [markdown]
# ### Shopping Cart Agent

# %%
class ToolCall(BaseModel):
    name: str
    arguments: dict

class ShoppingCartAgentResponse(BaseModel):
    answer: str = Field(description="Answer to the question.")
    final_answer: bool = False
    tool_calls: List[ToolCall] = []

# %%
@traceable(
    name="shopping_cart_agent",
    run_type="llm",
    metadata={"ls_provider": "openai", "ls_model_name": "gpt-4.1-mini"}
)
def shopping_cart_agent(state) -> dict:

   prompt_template =  """You are a part of the shopping assistant that can manage the user's shopping cart.

You will be given a conversation history and a list of tools, your task is to perform the action requested by the latest user query.

<Available tools>
{{ available_tools | tojson }}
</Available tools>

When making tool calls, use this exact format:
{
   "name": "tool_name",
   "arguments": {
         "parameter1": "value1",
         "parameter2": "value2",
   }
}

CRITICAL: All parameters must go inside the "arguments" object, not at the top level of the tool call.

Examples:
- Remove item from shopping cart:
{
   "name": "remove_from_shopping_cart",
   "arguments": {
         "product_id": "123",
         "user_id": "123",
         "cart_id": "456"
   }
}

- Add item to shopping cart:
{
   "name": "add_to_shopping_cart",
   "arguments": {
         "items": [
            {
               "product_id": "123",
               "quantity": 1
            },
            {
               "product_id": "456",
               "quantity": 2
            }
         ],
         "user_id": "123",
         "cart_id": "456"
   }
}

- Get shopping cart:
{
   "name": "get_shopping_cart",
   "arguments": {
         "user_id": "123",
         "cart_id": "456"
   }
}

After the tools are used you will get the outputs from the tools.

Additional information:
- User ID: {{ user_id }}
- Cart ID: {{ cart_id }}

CRITICAL RULES:
- If tool_calls has values, final_answer MUST be false
(You cannot call tools and return to coordinator in the same response)
- If final_answer is true, tool_calls MUST be []
(You must wait for tool results before returning to coordinator)
- If you need tool results before answering, set:
tool_calls=[...], final_answer=false
- After receiving tool results, you can then set:
tool_calls=[], final_answer=true

Instructions:
- Use names specificly provided in the available tools. Don't add any additional text to the names.
- You can run multipple tools at once.
- Once you get the tool results back, you might choose to performa additional tool calls.
- Once your suggested tool calls are done, set final_answer to True.
- Never set final_answer to True if you are suggesting tool_calls.
- As the final answer you should return an answer to the users query in a form of actions performed.
"""

   template = Template(prompt_template)
   
   prompt = template.render(
      available_tools=state.shopping_cart_agent.available_tools,
      user_id=state.user_id,
      cart_id=state.cart_id
   )

   messages = state.messages

   conversation = []

   for message in messages:
        conversation.append(convert_to_openai_messages(message))

   client = instructor.from_openai(OpenAI())

   response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        response_model=ProductQAAgentResponse,
        messages=[{"role": "system", "content": prompt}, *conversation],
        temperature=0, # while invoking the tools we do not need any variability in the answers
   )

   ai_message = format_ai_message(response)

   return {
      "messages": [ai_message],
      "shopping_cart_agent": {
        "iteration": state.shopping_cart_agent.iteration + 1,
        "final_answer": response.final_answer,
        "tool_calls": [tool_call.model_dump() for tool_call in response.tool_calls],
        "available_tools": state.shopping_cart_agent.available_tools
      },
      "answer": response.answer
   }

# %% [markdown]
# ### Intent Router

# %%
class IntentRouterResponse(BaseModel):
    user_intent: str
    answer: str

# %%
@traceable(
    name="agent_node",
    run_type="llm",
    metadata={"ls_provider": "openai", "ls_model_name": "gpt-4.1-mini"}
)
def intent_router_node(state):

   prompt_template =  """You are a part of a shopping assistant that routes user queries to the appropriate agents.

You will be given a conversation history, your task is to classify the intent of the user's latest query and output an appropriate classification.

The possible intents are:

- product_qa: The user is asking a question about a product. This can be a question about available products, their specifications, user reviews etc.
- shopping_cart: The user is asking to add or remove items from the shopping cart or questions about the current shopping cart.
- other: The user's latest query is not clear or not related to the shopping assistant.

Additional instructions:

- Write the intent classification to the user_intent field.
- If there is not enough context in the conversation history about the actions needed to be performed, do not classify as 'shopping_cart' or 'product_qa', instead classify as 'other'.
- If the classification is 'other', you should output the answer to the user's query trying to clarify the user's intent.
- If the classification is 'product_qa' or 'shopping_cart', you should only output the intent classification and no other text.
"""

   template = Template(prompt_template)
   
   prompt = template.render()

   messages = state.messages

   conversation = []

   for message in messages:
        conversation.append(convert_to_openai_messages(message))

   client = instructor.from_openai(OpenAI())

   response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        response_model=IntentRouterResponse,
        messages=[{"role": "system", "content": prompt}, *conversation],
        temperature=0.5,
   )

   if response.user_intent == "product_qa":
      ai_message = []
   else:
      ai_message = [AIMessage(
         content=response.answer,
      )]

   return {
      "messages": ai_message,
      "user_intent": response.user_intent,
      "answer": response.answer
      }

# %% [markdown]
# ### Product QA Agent Tool Use Router

# %%
def product_qa_agent_tool_router(state) -> str:
    """Decide whether to continue or end the product_qa_agent"""
    
    if state.product_qa_agent.final_answer:
        return "end"
    elif state.product_qa_agent.iteration > 4:
        return "end"
    elif len(state.product_qa_agent.tool_calls) > 0:
        return "tools"
    else:
        return "end"

# %% [markdown]
# ### Shopping Cart Agent Tool Use Router

# %%
def shopping_cart_agent_tool_router(state) -> str:
    """Decide whether to continue or end the shopping_cart_agent"""
    
    if state.shopping_cart_agent.final_answer:
        return "end"
    elif state.shopping_cart_agent.iteration > 2:
        return "end"
    elif len(state.shopping_cart_agent.tool_calls) > 0:
        return "tools"
    else:
        return "end"

# %% [markdown]
# ### User Intent Router

# %%
def user_intent_router(state) -> str:
    """Decide whether to continue or end"""
    
    if state.user_intent == "product_qa":
        return "product_qa_agent"
    elif state.user_intent == "shopping_cart":
        return "shopping_cart_agent"
    else:
        return "end"

# %%
class AgentProperties(BaseModel):
     # this is for each of our agents
    iteration: int = 0
    final_answer: bool = False
    available_tools: List[Dict[str, Any]] = []
    tool_calls: List[ToolCall] = []

class State(BaseModel):
    messages: Annotated[List[Any], add] = []
    user_intent: str = ""
    product_qa_agent: AgentProperties = Field(default_factory=AgentProperties)
    shopping_cart_agent: AgentProperties = Field(default_factory=AgentProperties)
    answer: str = ""
    references: Annotated[List[RAGUsedContext], add] = []
    user_id: str = ""
    cart_id: str = ""

# %% [markdown]
# ### Graph

# %%
workflow = StateGraph(State)

product_qa_agent_tools = [get_formatted_item_context, get_formatted_reviews_context]
product_qa_agent_tool_node = ToolNode(product_qa_agent_tools)
product_qa_agent_tool_descriptions = get_tool_descriptions(product_qa_agent_tools)

shopping_cart_agent_tools = [add_to_shopping_cart, remove_from_cart, get_shopping_cart]
shopping_cart_agent_tool_node = ToolNode(shopping_cart_agent_tools)
shopping_cart_agent_tool_descriptions = get_tool_descriptions(shopping_cart_agent_tools)

#agent nodes
workflow.add_node("product_qa_agent", product_qa_agent)
workflow.add_node("shopping_cart_agent", shopping_cart_agent)
workflow.add_node("intent_router", intent_router_node)

#tool nodes
workflow.add_node("product_qa_agent_tool_node", product_qa_agent_tool_node)
workflow.add_node("shopping_cart_agent_tool_node", shopping_cart_agent_tool_node)

workflow.add_edge(START, "intent_router")

workflow.add_conditional_edges(
    "intent_router",
    user_intent_router,
    {
        "product_qa_agent": "product_qa_agent",
        "shopping_cart_agent": "shopping_cart_agent",
        "end": END
    }
)

workflow.add_conditional_edges(
    "product_qa_agent",
    product_qa_agent_tool_router,
    {
        "tools": "product_qa_agent_tool_node",
        "end": END
    }
)

workflow.add_conditional_edges(
    "shopping_cart_agent",
    shopping_cart_agent_tool_router,
    {
        "tools": "shopping_cart_agent_tool_node",
        "end": END
    }
)

workflow.add_edge("product_qa_agent_tool_node", "product_qa_agent")
workflow.add_edge("shopping_cart_agent_tool_node", "shopping_cart_agent")

graph = workflow.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Test Conversation

# %%
initial_state = {
    "messages": [{"role": "user", "content": "What is the weather today?"}],
    "user_id": "123",
    "cart_id": "456",
    "product_qa_agent": {
        "iteration": 0,
        "final_answer": False,
        "available_tools": product_qa_agent_tool_descriptions,
        "tool_calls": []
    },
    "shopping_cart_agent": {
        "iteration": 0,
        "final_answer": False,
        "available_tools": shopping_cart_agent_tool_descriptions,
        "tool_calls": []
    }
}
config = {"configurable": {"thread_id": "test00003000"}}

with PostgresSaver.from_conn_string("postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db") as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["debug", "updates"]
    ):
        print(chunk)
# Out:
# ('debug', {'step': -1, 'timestamp': '2025-11-29T08:46:34.156941+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00003000', 'checkpoint_id': '1f0ccffe-8b63-6d64-bfff-c66f9bbab317'}}, 'parent_config': None, 'values': {'messages': [], 'references': []}, 'metadata': {'source': 'input', 'step': -1, 'parents': {}}, 'next': ['__start__'], 'tasks': [{'id': '779023f9-1d21-d49c-e422-598b50d443cb', 'name': '__start__', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 0, 'timestamp': '2025-11-29T08:46:34.169729+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00003000', 'checkpoint_id': '1f0ccffe-8b95-6fe4-8000-30af116faa20'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00003000', 'checkpoint_id': '1f0ccffe-8b63-6d64-bfff-c66f9bbab317'}}, 'values': {'messages': [{'role': 'user', 'content': 'What is the weather today?'}], 'product_qa_agent': {'iteration': 0, 'final_answer': False, 'available_tools': [{'name': 'get_formatted_item_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], 'tool_calls': []}, 'shopping_cart_agent': {'iteration': 0, 'final_answer': False, 'available_tools': [{'name': 'add_to_shopping_cart', 'description': 'Add a list of provided items to the shopping cart.', 'parameters': {'type': 'object', 'properties': {'items': {'type': 'array', 'description': 'A list of items to add to the shopping cart. Each item is a dictionary with the following keys: product_id, quantity.'}, 'user_id': {'type': 'string', 'description': 'The id of the user to add the items to the shopping cart.'}, 'cart_id': {'type': 'string', 'description': 'The id of the shopping cart to add the items to.'}}}, 'required': ['items', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': 'A list of the items added to the shopping cart.'}}, {'name': 'remove_from_cart', 'description': 'Remove an item completely from the shopping cart.', 'parameters': {'type': 'object', 'properties': {'product_id': {'type': 'string', 'description': 'Product ID to remove'}, 'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['product_id', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': "True if item was removed, False if item wasn't found"}}, {'name': 'get_shopping_cart', 'description': "Retrieve all items in a user's shopping cart.", 'parameters': {'type': 'object', 'properties': {'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['user_id', 'cart_id'], 'returns': {'type': 'array', 'description': 'List of dictionaries containing cart items'}}], 'tool_calls': []}, 'references': [], 'user_id': '123', 'cart_id': '456'}, 'metadata': {'source': 'loop', 'step': 0, 'parents': {}}, 'next': ['intent_router'], 'tasks': [{'id': '876d0f36-ae09-ea8b-fa66-8e33b138e2b9', 'name': 'intent_router', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 1, 'timestamp': '2025-11-29T08:46:34.169739+00:00', 'type': 'task', 'payload': {'id': '876d0f36-ae09-ea8b-fa66-8e33b138e2b9', 'name': 'intent_router', 'input': State(messages=[{'role': 'user', 'content': 'What is the weather today?'}], user_intent='', product_qa_agent=AgentProperties(iteration=0, final_answer=False, available_tools=[{'name': 'get_formatted_item_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], tool_calls=[]), shopping_cart_agent=AgentProperties(iteration=0, final_answer=False, available_tools=[{'name': 'add_to_shopping_cart', 'description': 'Add a list of provided items to the shopping cart.', 'parameters': {'type': 'object', 'properties': {'items': {'type': 'array', 'description': 'A list of items to add to the shopping cart. Each item is a dictionary with the following keys: product_id, quantity.'}, 'user_id': {'type': 'string', 'description': 'The id of the user to add the items to the shopping cart.'}, 'cart_id': {'type': 'string', 'description': 'The id of the shopping cart to add the items to.'}}}, 'required': ['items', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': 'A list of the items added to the shopping cart.'}}, {'name': 'remove_from_cart', 'description': 'Remove an item completely from the shopping cart.', 'parameters': {'type': 'object', 'properties': {'product_id': {'type': 'string', 'description': 'Product ID to remove'}, 'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['product_id', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': "True if item was removed, False if item wasn't found"}}, {'name': 'get_shopping_cart', 'description': "Retrieve all items in a user's shopping cart.", 'parameters': {'type': 'object', 'properties': {'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['user_id', 'cart_id'], 'returns': {'type': 'array', 'description': 'List of dictionaries containing cart items'}}], tool_calls=[]), answer='', references=[], user_id='123', cart_id='456'), 'triggers': ('branch:to:intent_router',)}})
# ('updates', {'intent_router': {'messages': [AIMessage(content='I can help with shopping-related queries. Could you please specify if you need assistance with products, orders, or something else related to shopping?', additional_kwargs={}, response_metadata={})], 'user_intent': 'other', 'answer': 'I can help with shopping-related queries. Could you please specify if you need assistance with products, orders, or something else related to shopping?'}})
# ('debug', {'step': 1, 'timestamp': '2025-11-29T08:46:35.117329+00:00', 'type': 'task_result', 'payload': {'id': '876d0f36-ae09-ea8b-fa66-8e33b138e2b9', 'name': 'intent_router', 'error': None, 'result': {'messages': [AIMessage(content='I can help with shopping-related queries. Could you please specify if you need assistance with products, orders, or something else related to shopping?', additional_kwargs={}, response_metadata={})], 'user_intent': 'other', 'answer': 'I can help with shopping-related queries. Could you please specify if you need assistance with products, orders, or something else related to shopping?'}, 'interrupts': []}})
# ('debug', {'step': 1, 'timestamp': '2025-11-29T08:46:35.117743+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00003000', 'checkpoint_id': '1f0ccffe-94a5-609e-8001-7bf068f111b8'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00003000', 'checkpoint_id': '1f0ccffe-8b95-6fe4-8000-30af116faa20'}}, 'values': {'messages': [{'role': 'user', 'content': 'What is the weather today?'}, AIMessage(content='I can help with shopping-related queries. Could you please specify if you need assistance with products, orders, or something else related to shopping?', additional_kwargs={}, response_metadata={})], 'user_intent': 'other', 'product_qa_agent': {'iteration': 0, 'final_answer': False, 'available_tools': [{'name': 'get_formatted_item_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], 'tool_calls': []}, 'shopping_cart_agent': {'iteration': 0, 'final_answer': False, 'available_tools': [{'name': 'add_to_shopping_cart', 'description': 'Add a list of provided items to the shopping cart.', 'parameters': {'type': 'object', 'properties': {'items': {'type': 'array', 'description': 'A list of items to add to the shopping cart. Each item is a dictionary with the following keys: product_id, quantity.'}, 'user_id': {'type': 'string', 'description': 'The id of the user to add the items to the shopping cart.'}, 'cart_id': {'type': 'string', 'description': 'The id of the shopping cart to add the items to.'}}}, 'required': ['items', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': 'A list of the items added to the shopping cart.'}}, {'name': 'remove_from_cart', 'description': 'Remove an item completely from the shopping cart.', 'parameters': {'type': 'object', 'properties': {'product_id': {'type': 'string', 'description': 'Product ID to remove'}, 'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['product_id', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': "True if item was removed, False if item wasn't found"}}, {'name': 'get_shopping_cart', 'description': "Retrieve all items in a user's shopping cart.", 'parameters': {'type': 'object', 'properties': {'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['user_id', 'cart_id'], 'returns': {'type': 'array', 'description': 'List of dictionaries containing cart items'}}], 'tool_calls': []}, 'answer': 'I can help with shopping-related queries. Could you please specify if you need assistance with products, orders, or something else rela ...

# %%
initial_state = {
    "messages": [{"role": "user", "content": "Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?"}],
    "user_id": "123",
    "cart_id": "456",
    "product_qa_agent": {
        "iteration": 0,
        "final_answer": False,
        "available_tools": product_qa_agent_tool_descriptions,
        "tool_calls": []
    },
    "shopping_cart_agent": {
        "iteration": 0,
        "final_answer": False,
        "available_tools": shopping_cart_agent_tool_descriptions,
        "tool_calls": []
    }
}
config = {"configurable": {"thread_id": "test00001006"}}

with PostgresSaver.from_conn_string("postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db") as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["debug", "updates"]
    ):
        print(chunk)
# Out:
# ('debug', {'step': -1, 'timestamp': '2025-11-29T08:56:36.949104+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-0026-65e6-bfff-b1564a8b76b9'}}, 'parent_config': None, 'values': {'messages': [], 'references': []}, 'metadata': {'source': 'input', 'step': -1, 'parents': {}}, 'next': ['__start__'], 'tasks': [{'id': 'a31c395b-97b9-28b4-f858-fd481d6c439c', 'name': '__start__', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 0, 'timestamp': '2025-11-29T08:56:36.950435+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-002b-608c-8000-099023709ad1'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-0026-65e6-bfff-b1564a8b76b9'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}], 'product_qa_agent': {'iteration': 0, 'final_answer': False, 'available_tools': [{'name': 'get_formatted_item_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], 'tool_calls': []}, 'shopping_cart_agent': {'iteration': 0, 'final_answer': False, 'available_tools': [{'name': 'add_to_shopping_cart', 'description': 'Add a list of provided items to the shopping cart.', 'parameters': {'type': 'object', 'properties': {'items': {'type': 'array', 'description': 'A list of items to add to the shopping cart. Each item is a dictionary with the following keys: product_id, quantity.'}, 'user_id': {'type': 'string', 'description': 'The id of the user to add the items to the shopping cart.'}, 'cart_id': {'type': 'string', 'description': 'The id of the shopping cart to add the items to.'}}}, 'required': ['items', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': 'A list of the items added to the shopping cart.'}}, {'name': 'remove_from_cart', 'description': 'Remove an item completely from the shopping cart.', 'parameters': {'type': 'object', 'properties': {'product_id': {'type': 'string', 'description': 'Product ID to remove'}, 'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['product_id', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': "True if item was removed, False if item wasn't found"}}, {'name': 'get_shopping_cart', 'description': "Retrieve all items in a user's shopping cart.", 'parameters': {'type': 'object', 'properties': {'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['user_id', 'cart_id'], 'returns': {'type': 'array', 'description': 'List of dictionaries containing cart items'}}], 'tool_calls': []}, 'references': [], 'user_id': '123', 'cart_id': '456'}, 'metadata': {'source': 'loop', 'step': 0, 'parents': {}}, 'next': ['intent_router'], 'tasks': [{'id': '65813cbd-4b30-2fbf-dd08-d733bb1ccc38', 'name': 'intent_router', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 1, 'timestamp': '2025-11-29T08:56:36.950443+00:00', 'type': 'task', 'payload': {'id': '65813cbd-4b30-2fbf-dd08-d733bb1ccc38', 'name': 'intent_router', 'input': State(messages=[{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}], user_intent='', product_qa_agent=AgentProperties(iteration=0, final_answer=False, available_tools=[{'name': 'get_formatted_item_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], tool_calls=[]), shopping_cart_agent=AgentProperties(iteration=0, final_answer=False, available_tools=[{'name': 'add_to_shopping_cart', 'description': 'Add a list of provided items to the shopping cart.', 'parameters': {'type': 'object', 'properties': {'items': {'type': 'array', 'description': 'A list of items to add to the shopping cart. Each item is a dictionary with the following keys: product_id, quantity.'}, 'user_id': {'type': 'string', 'description': 'The id of the user to add the items to the shopping cart.'}, 'cart_id': {'type': 'string', 'description': 'The id of the shopping cart to add the items to.'}}}, 'required': ['items', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': 'A list of the items added to the shopping cart.'}}, {'name': 'remove_from_cart', 'description': 'Remove an item completely from the shopping cart.', 'parameters': {'type': 'object', 'properties': {'product_id': {'type': 'string', 'description': 'Product ID to remove'}, 'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['product_id', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': "True if item was removed, False if item wasn't found"}}, {'name': 'get_shopping_cart', 'description': "Retrieve all items in a user's shopping cart.", 'parameters': {'type': 'object', 'properties': {'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['user_id', 'cart_id'], 'returns': {'type': 'array', 'description': 'List of dictionaries containing cart items'}}], tool_calls=[]), answer='', references=[], user_id='123', cart_id='456'), 'triggers': ('branch:to:intent_router',)}})
# ('updates', {'intent_router': {'messages': [], 'user_intent': 'product_qa', 'answer': 'You are interested in earphones and a laptop along with some positive and negative reviews for each. I can help you with that. Let me provide you with some options and their reviews.'}})
# ('debug', {'step': 1, 'timestamp': '2025-11-29T08:56:37.893843+00:00', 'type': 'task_result', 'payload': {'id': '65813cbd-4b30-2fbf-dd08-d733bb1ccc38', 'name': 'intent_router', 'error': None, 'result': {'messages': [], 'user_intent': 'product_qa', 'answer': 'You are interested in earphones and a laptop along with some positive and negative reviews for each. I can help you with that. Let me provide you with some options and their reviews.'}, 'interrupts': []}})
# ('debug', {'step': 1, 'timestamp': '2025-11-29T08:56:37.894541+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-092b-6af6-8001-1e43a8c64c74'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-002b-608c-8000-099023709ad1'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}], 'user_intent': 'product_qa', 'product_qa_agent': {'iteration': 0, 'final_answer': False, 'available_tools': [{'name': 'get_formatted_item_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], 'tool_calls': []}, 'shopping_cart_agent': {'iteration': 0, 'final_answer': False, 'available_tools': [{'name': 'add_to_shopping_cart', 'description': 'Add a list of provided items to the shopping cart.', 'parameters': {'type': 'object', 'properties': {'items': {'type': 'array', 'description': 'A list of items to add to the shopping cart. Each item is a dictionary with the following keys: product_id, quantity.'}, 'user_id': {'type': 'string', 'description': 'The id of the user to add the items to the shopping cart.'}, 'cart_id': {'type': 'string', 'description': 'The id of the shopping cart to add the items to.'}}}, 'required': ['items', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': 'A list of the items added to the shopping cart.'}}, {'name': 'remove_from_cart', 'description': 'Remove an item completely from the shopping cart.', 'parameters': {'type': 'object', 'properties': {'product_id': {'type': 'string', 'description': 'Product ID to remove'}, 'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['product_id', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': "True if item was removed, False if item wasn't found"}}, {'name': 'get_shopping_cart', 'description': "Retrieve all items in a user's shopping cart.", 'parameters': {'type': 'object', 'properties': {'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['user_id', 'cart_id'], 'returns': {'type': 'array', 'description': 'List of dictionaries containing cart items'}}], 'tool_calls': []}, 'answer': 'You are interested in earphones and a laptop along with some positive and negative reviews for each. I can help you with that. Let me provide you with some options and their reviews.', 'references': [], 'user_id': '123', 'cart_id': '456'}, 'metadata': {'s ...
# ('debug', {'step': 2, 'timestamp': '2025-11-29T08:56:37.894563+00:00', 'type': 'task', 'payload': {'id': '50373cbd-886e-edc5-ed4d-3c7ece636cf5', 'name': 'product_qa_agent', 'input': State(messages=[{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}], user_intent='product_qa', product_qa_agent=AgentProperties(iteration=0, final_answer=False, available_tools=[{'name': 'get_formatted_item_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], tool_calls=[]), shopping_cart_agent=AgentProperties(iteration=0, final_answer=False, available_tools=[{'name': 'add_to_shopping_cart', 'description': 'Add a list of provided items to the shopping cart.', 'parameters': {'type': 'object', 'properties': {'items': {'type': 'array', 'description': 'A list of items to add to the shopping cart. Each item is a dictionary with the following keys: product_id, quantity.'}, 'user_id': {'type': 'string', 'description': 'The id of the user to add the items to the shopping cart.'}, 'cart_id': {'type': 'string', 'description': 'The id of the shopping cart to add the items to.'}}}, 'required': ['items', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': 'A list of the items added to the shopping cart.'}}, {'name': 'remove_from_cart', 'description': 'Remove an item completely from the shopping cart.', 'parameters': {'type': 'object', 'properties': {'product_id': {'type': 'string', 'description': 'Product ID to remove'}, 'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['product_id', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': "True if item was removed, False if item wasn't found"}}, {'name': 'get_shopping_cart', 'description': "Retrieve all items in a user's shopping cart.", 'parameters': {'type': 'object', 'properties': {'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['user_id', 'cart_id'], 'returns': {'type': 'array', 'description': 'List of dictionaries containing cart items'}}], tool_calls=[]), answer='You are interested in earphones and a laptop along with some positive and negative reviews for each. I can help you with that. Let me provide you with some options and their reviews.', references=[], user_id='123', cart_id='456'), 'triggers': ('branch:to:product_qa_agent',)}})
# ('updates', {'product_qa_agent': {'messages': [AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}])], 'product_qa_agent': {'iteration': 1, 'final_answer': False, 'tool_calls': [{'name': 'get_formatted_item_context', 'arguments': {'query': 'earphones', 'top_k': 5}}, {'name': 'get_formatted_item_context', 'arguments': {'query': 'laptop', 'top_k': 5}}], 'available_tools': [{'name': 'get_formatted_item_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}]}, 'answer': 'I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', 'references': []}})
# ('debug', {'step': 2, 'timestamp': '2025-11-29T08:56:40.619645+00:00', 'type': 'task_result', 'payload': {'id': '50373cbd-886e-edc5-ed4d-3c7ece636cf5', 'name': 'product_qa_agent', 'error': None, 'result': {'messages': [AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}])], 'product_qa_agent': {'iteration': 1, 'final_answer': False, 'tool_calls': [{'name': 'get_formatted_item_context', 'arguments': {'query': 'earphones', 'top_k': 5}}, {'name': 'get_formatted_item_context', 'arguments': {'query': 'laptop', 'top_k': 5}}], 'available_tools': [{'name': 'get_formatted_item_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}]}, 'answer': 'I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', 'references': []}, 'interrupts': []}})
# ('debug', {'step': 2, 'timestamp': '2025-11-29T08:56:40.620060+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-232a-6344-8002-f98fd53b5278'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-092b-6af6-8001-1e43a8c64c74'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}])], 'user_intent': 'product_qa', 'product_qa_agent': {'iteration': 1, 'final_answer': False, 'tool_calls': [{'name': 'get_formatted_item_context', 'arguments': {'query': 'earphones', 'top_k': 5}}, {'name': 'get_formatted_item_context', 'arguments': {'query': 'laptop', 'top_k': 5}}], 'available_tools': [{'name': 'get_formatted_item_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}]}, 'shopping_cart_agent': {'iteration': 0, 'final_answer': False, 'available_tools': [{'name': 'add_to_shopping_cart', 'description': 'Add a list of provided items to the shopping cart.', 'parameters': {'type': 'object', 'properties': {'items': {'type': 'array', 'description': 'A list of items to add to the shopping cart. Each item is a dictionary with the following keys: product_id, quantity.'}, 'user_id': {'type': 'string', 'description': 'The id of the user to add the items to the shopping cart.'}, 'cart_id': {'type': 'string', 'description': 'The id of the shopping cart to add the items to.'}}}, 'required': ['items', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': 'A list of the items added to the shopping cart.'}}, {'name': 'remove_from_cart', 'description': 'Remove an item completely from the shopping cart.', 'parameters': {'type': 'object', 'properties': {'product_id': {'type': 'string', 'description': 'Product ID to remove'}, 'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['product_id', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': "True if item was removed, False if item wasn't found"}}, {'name': 'get_shopping_cart', 'description': "Retrieve all items in a user's sh ...
# ('debug', {'step': 3, 'timestamp': '2025-11-29T08:56:40.620069+00:00', 'type': 'task', 'payload': {'id': '12bf012b-db3f-18bc-096d-76cf31c76dfd', 'name': 'product_qa_agent_tool_node', 'input': State(messages=[{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}])], user_intent='product_qa', product_qa_agent=AgentProperties(iteration=1, final_answer=False, available_tools=[{'name': 'get_formatted_item_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}], tool_calls=[ToolCall(name='get_formatted_item_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_item_context', arguments={'query': 'laptop', 'top_k': 5})]), shopping_cart_agent=AgentProperties(iteration=0, final_answer=False, available_tools=[{'name': 'add_to_shopping_cart', 'description': 'Add a list of provided items to the shopping cart.', 'parameters': {'type': 'object', 'properties': {'items': {'type': 'array', 'description': 'A list of items to add to the shopping cart. Each item is a dictionary with the following keys: product_id, quantity.'}, 'user_id': {'type': 'string', 'description': 'The id of the user to add the items to the shopping cart.'}, 'cart_id': {'type': 'string', 'description': 'The id of the shopping cart to add the items to.'}}}, 'required': ['items', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': 'A list of the items added to the shopping cart.'}}, {'name': 'remove_from_cart', 'description': 'Remove an item completely from the shopping cart.', 'parameters': {'type': 'object', 'properties': {'product_id': {'type': 'string', 'description': 'Product ID to remove'}, 'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['product_id', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': "True if item was removed, False if item wasn't found"}}, {'name': 'get_shopping_cart', 'description': "Retrieve all items in a user's shopping cart.", 'parameters': {'type': 'object', 'properties': {'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ...
# ('updates', {'product_qa_agent_tool_node': {'messages': [ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super comfortable the ergonomic in-ear design can maintain a firm fit every time, ensuring proper fit and extra comfort. High-fidelity sound quality-earbud headphones provide clear top-level sound quality in the recording studio, with strong bass, strong midrange, and precise treble response, A9 can bring you delightful music. Wide compatibility-very is suitable for iPhone devices, Android smartphones, iPods, iPads, MP3 players, music speakers, and all other interface devices with 3.5mm headphone jack. High-quality service-If you have any questions, please feel free to contact us, we will reply in time. We hope you enjoy a pleasant shopping experience.\n- ID: B0BX2RDHB8, rating: 4.0, description: KNTARU Earplugs Earphones，Earphones That Look Like earplugs，Earphones Disguised as earplugs，Noise Suppression，Hearing Protection，Waterproof，for Work，Study，Fitness，Noisy Places【INCLUDES】 NRR value: 28dB ,Color: blue + orange, Connection ...
# ('debug', {'step': 3, 'timestamp': '2025-11-29T08:56:42.187372+00:00', 'type': 'task_result', 'payload': {'id': '12bf012b-db3f-18bc-096d-76cf31c76dfd', 'name': 'product_qa_agent_tool_node', 'error': None, 'result': {'messages': [ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super comfortable the ergonomic in-ear design can maintain a firm fit every time, ensuring proper fit and extra comfort. High-fidelity sound quality-earbud headphones provide clear top-level sound quality in the recording studio, with strong bass, strong midrange, and precise treble response, A9 can bring you delightful music. Wide compatibility-very is suitable for iPhone devices, Android smartphones, iPods, iPads, MP3 players, music speakers, and all other interface devices with 3.5mm headphone jack. High-quality service-If you have any questions, please feel free to contact us, we will reply in time. We hope you enjoy a pleasant shopping experience.\n- ID: B0BX2RDHB8, rating: 4.0, description: KNTARU Earplugs Earphones，Earphones That Look Like earplugs，Ear ...
# ('debug', {'step': 3, 'timestamp': '2025-11-29T08:56:42.188316+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-321f-6016-8003-47357daa570e'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-232a-6344-8002-f98fd53b5278'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super co ...
# ('debug', {'step': 4, 'timestamp': '2025-11-29T08:56:42.188321+00:00', 'type': 'task', 'payload': {'id': 'f7a5f505-2d33-e315-a16d-84cc44ff1762', 'name': 'product_qa_agent', 'input': State(messages=[{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super comfortable the ergonomic in-ear design can maintain a firm fit every time, ensuring proper fit and extra comfort. High-fidelity sound quality-earbud headphones provide clear top-level sound quality in the recordin ...
# ('updates', {'product_qa_agent': {'messages': [AIMessage(content='Here are some earphones and laptops for you along with positive and negative reviews:\n\nEarphones:\n1. aeac Wireless Earbuds (ID: B0BBFNHMYX)\n   - Positive: Wireless Bluetooth, IPX5 Waterproof, built-in mic.\n   - Negative: No specific negative reviews found.\n\n2. 100SEASHELL Long Cord Wired Earbuds (ID: B09PYK37K4)\n   - Positive: Excellent sound quality with enhanced bass, comfortable ergonomic metal shell, magnetic function for storage.\n   - Negative: No specific negative reviews found.\n\n3. 6 Pack Earbuds Headphone Wired with Microphone (ID: B09Y5DZW52)\n   - Positive: Built-in microphones, noise isolating, super comfortable ergonomic design, high-fidelity sound quality, wide compatibility.\n   - Negative: No specific negative reviews found.\n\n4. KNTARU Earplugs Earphones (ID: B0BX2RDHB8)\n   - Positive: Noise suppression, hearing protection, waterproof, suitable for noisy places, excellent sound insulation.\n   - Negative: No specific negative reviews found.\n\nLaptops (Laptop Stands and Accessories):\n1. UPGRAVITY Laptop Desk Mount (ID: B0B7WBD4V7)\n   - Positive: Fits laptops up to 17", ergonomic height adjustment, full motion arm, cable management system, easy installation.\n   - Negative: No specific negative reviews found.\n\n2. Nulaxy Laptop Stand for Desk (ID: B0978VTJX8)\n   - Positive: Fits laptops 10-17", adjustable height from 1.2" to 20", ergonomic design, durable, heat dissipation.\n   - Negative: Some wobbling at certain height levels while typing.\n\n3. STOON Laptop Stand Adjustable Height (ID: B0C9QY7568)\n   - Positive: Durable aluminum design, adjustable angle and height, stable and protective, cooling and foldable, broad compatibility.\n   - Negative: No specific negative reviews found.\n\n4. Laptop Stand for Desk, Aluminum Alloy Laptop Holder (ID: B08BYFJTD5)\n   - Positive: Portable and foldable, adjustable and stable, heat dissipation, wide compatibility, anti-slip and durable.\n   - Negative: No specific negative reviews found.\n\nIf you want, I can also provide more detailed reviews for each item.', additional_kwargs={}, response_metadata={})], 'product_qa_agent': {'iteration': 2, 'final_answer': True, 'tool_calls': [], 'available_tools': [{'name': 'get_formatted_item_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}]}, 'answer': 'Here are some earphones and laptops for you along with positive and negative reviews:\n\nEarphones:\n1. aeac Wireless Earbuds (ID: B0BBFNHMYX)\n   - Positive: Wireless Bluetooth, IPX5 Waterproof, built-in mic.\n   - Negative: No specific negative reviews found.\n\n2. 100SEASHELL Long Cord Wired Earbuds (ID: B09PYK37K4)\n ...
# ('debug', {'step': 4, 'timestamp': '2025-11-29T08:56:50.299160+00:00', 'type': 'task_result', 'payload': {'id': 'f7a5f505-2d33-e315-a16d-84cc44ff1762', 'name': 'product_qa_agent', 'error': None, 'result': {'messages': [AIMessage(content='Here are some earphones and laptops for you along with positive and negative reviews:\n\nEarphones:\n1. aeac Wireless Earbuds (ID: B0BBFNHMYX)\n   - Positive: Wireless Bluetooth, IPX5 Waterproof, built-in mic.\n   - Negative: No specific negative reviews found.\n\n2. 100SEASHELL Long Cord Wired Earbuds (ID: B09PYK37K4)\n   - Positive: Excellent sound quality with enhanced bass, comfortable ergonomic metal shell, magnetic function for storage.\n   - Negative: No specific negative reviews found.\n\n3. 6 Pack Earbuds Headphone Wired with Microphone (ID: B09Y5DZW52)\n   - Positive: Built-in microphones, noise isolating, super comfortable ergonomic design, high-fidelity sound quality, wide compatibility.\n   - Negative: No specific negative reviews found.\n\n4. KNTARU Earplugs Earphones (ID: B0BX2RDHB8)\n   - Positive: Noise suppression, hearing protection, waterproof, suitable for noisy places, excellent sound insulation.\n   - Negative: No specific negative reviews found.\n\nLaptops (Laptop Stands and Accessories):\n1. UPGRAVITY Laptop Desk Mount (ID: B0B7WBD4V7)\n   - Positive: Fits laptops up to 17", ergonomic height adjustment, full motion arm, cable management system, easy installation.\n   - Negative: No specific negative reviews found.\n\n2. Nulaxy Laptop Stand for Desk (ID: B0978VTJX8)\n   - Positive: Fits laptops 10-17", adjustable height from 1.2" to 20", ergonomic design, durable, heat dissipation.\n   - Negative: Some wobbling at certain height levels while typing.\n\n3. STOON Laptop Stand Adjustable Height (ID: B0C9QY7568)\n   - Positive: Durable aluminum design, adjustable angle and height, stable and protective, cooling and foldable, broad compatibility.\n   - Negative: No specific negative reviews found.\n\n4. Laptop Stand for Desk, Aluminum Alloy Laptop Holder (ID: B08BYFJTD5)\n   - Positive: Portable and foldable, adjustable and stable, heat dissipation, wide compatibility, anti-slip and durable.\n   - Negative: No specific negative reviews found.\n\nIf you want, I can also provide more detailed reviews for each item.', additional_kwargs={}, response_metadata={})], 'product_qa_agent': {'iteration': 2, 'final_answer': True, 'tool_calls': [], 'available_tools': [{'name': 'get_formatted_item_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}, {'name': 'get_formatted_reviews_context', 'description': 'Get the top k reviews matching a query for a list of prefiltered items.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k reviews for'}, 'item_list': {'type': 'array', 'description': 'The list of item IDs to prefilter for before running the query'}, 'top_k': {'type': 'integer', 'description': 'The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered', 'default': 5}}}, 'required': ['query', 'item_list'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.'}}]}, 'answer': 'Here are some earphones and laptops for you along with positive and negative reviews:\n\nEarphones:\n1. aeac Wireless Earbuds (ID: B0BBFNHMYX)\n   - P ...
# ('debug', {'step': 4, 'timestamp': '2025-11-29T08:56:50.299537+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-7f7a-622a-8004-7e09ed978f9a'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-321f-6016-8003-47357daa570e'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super co ...

# %%
initial_state = {
    "messages": [{"role": "user", "content": "Can you add aeac Wireless Earbuds to my cart?"}],
    "user_id": "erewertyw",
    "cart_id": "ewyewyerwy",
    "product_qa_agent": {
        "iteration": 0,
        "final_answer": False,
        "available_tools": product_qa_agent_tool_descriptions,
        "tool_calls": []
    },
    "shopping_cart_agent": {
        "iteration": 0,
        "final_answer": False,
        "available_tools": shopping_cart_agent_tool_descriptions,
        "tool_calls": []
    }
}
config = {"configurable": {"thread_id": "test00001006"}}

with PostgresSaver.from_conn_string("postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db") as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["debug", "updates"]
    ):
        print(chunk)
# Out:
# ('debug', {'step': 5, 'timestamp': '2025-11-29T08:56:50.417924+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-809a-6376-8005-f4fbd94ac393'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-7f7a-622a-8004-7e09ed978f9a'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super co ...
# ('debug', {'step': 6, 'timestamp': '2025-11-29T08:56:50.430122+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-809d-6350-8006-18ab7b9c6d6b'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-809a-6376-8005-f4fbd94ac393'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super co ...
# ('debug', {'step': 7, 'timestamp': '2025-11-29T08:56:50.430139+00:00', 'type': 'task', 'payload': {'id': '5dc6c44b-5209-bb30-9383-369762143979', 'name': 'intent_router', 'input': State(messages=[{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super comfortable the ergonomic in-ear design can maintain a firm fit every time, ensuring proper fit and extra comfort. High-fidelity sound quality-earbud headphones provide clear top-level sound quality in the recording s ...
# ('updates', {'intent_router': {'messages': [AIMessage(content='Adding aeac Wireless Earbuds to your cart.', additional_kwargs={}, response_metadata={})], 'user_intent': 'shopping_cart', 'answer': 'Adding aeac Wireless Earbuds to your cart.'}})
# ('debug', {'step': 7, 'timestamp': '2025-11-29T08:56:51.045156+00:00', 'type': 'task_result', 'payload': {'id': '5dc6c44b-5209-bb30-9383-369762143979', 'name': 'intent_router', 'error': None, 'result': {'messages': [AIMessage(content='Adding aeac Wireless Earbuds to your cart.', additional_kwargs={}, response_metadata={})], 'user_intent': 'shopping_cart', 'answer': 'Adding aeac Wireless Earbuds to your cart.'}, 'interrupts': []}})
# ('debug', {'step': 7, 'timestamp': '2025-11-29T08:56:51.045364+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-8697-6184-8007-1773735d213d'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-809d-6350-8006-18ab7b9c6d6b'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super co ...
# ('debug', {'step': 8, 'timestamp': '2025-11-29T08:56:51.045371+00:00', 'type': 'task', 'payload': {'id': 'bbdb6c29-04ae-2453-a289-e93d150c2370', 'name': 'shopping_cart_agent', 'input': State(messages=[{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super comfortable the ergonomic in-ear design can maintain a firm fit every time, ensuring proper fit and extra comfort. High-fidelity sound quality-earbud headphones provide clear top-level sound quality in the recor ...
# ('updates', {'shopping_cart_agent': {'messages': [AIMessage(content='Adding aeac Wireless Earbuds to your cart.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'add_to_shopping_cart', 'args': {'items': [{'product_id': 'B0BBFNHMYX', 'quantity': 1}], 'user_id': 'erewertyw', 'cart_id': 'ewyewyerwy'}, 'id': 'call_0', 'type': 'tool_call'}])], 'shopping_cart_agent': {'iteration': 1, 'final_answer': False, 'tool_calls': [{'name': 'add_to_shopping_cart', 'arguments': {'items': [{'product_id': 'B0BBFNHMYX', 'quantity': 1}], 'user_id': 'erewertyw', 'cart_id': 'ewyewyerwy'}}], 'available_tools': [{'name': 'add_to_shopping_cart', 'description': 'Add a list of provided items to the shopping cart.', 'parameters': {'type': 'object', 'properties': {'items': {'type': 'array', 'description': 'A list of items to add to the shopping cart. Each item is a dictionary with the following keys: product_id, quantity.'}, 'user_id': {'type': 'string', 'description': 'The id of the user to add the items to the shopping cart.'}, 'cart_id': {'type': 'string', 'description': 'The id of the shopping cart to add the items to.'}}}, 'required': ['items', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': 'A list of the items added to the shopping cart.'}}, {'name': 'remove_from_cart', 'description': 'Remove an item completely from the shopping cart.', 'parameters': {'type': 'object', 'properties': {'product_id': {'type': 'string', 'description': 'Product ID to remove'}, 'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['product_id', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': "True if item was removed, False if item wasn't found"}}, {'name': 'get_shopping_cart', 'description': "Retrieve all items in a user's shopping cart.", 'parameters': {'type': 'object', 'properties': {'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['user_id', 'cart_id'], 'returns': {'type': 'array', 'description': 'List of dictionaries containing cart items'}}]}, 'answer': 'Adding aeac Wireless Earbuds to your cart.'}})
# ('debug', {'step': 8, 'timestamp': '2025-11-29T08:56:54.402733+00:00', 'type': 'task_result', 'payload': {'id': 'bbdb6c29-04ae-2453-a289-e93d150c2370', 'name': 'shopping_cart_agent', 'error': None, 'result': {'messages': [AIMessage(content='Adding aeac Wireless Earbuds to your cart.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'add_to_shopping_cart', 'args': {'items': [{'product_id': 'B0BBFNHMYX', 'quantity': 1}], 'user_id': 'erewertyw', 'cart_id': 'ewyewyerwy'}, 'id': 'call_0', 'type': 'tool_call'}])], 'shopping_cart_agent': {'iteration': 1, 'final_answer': False, 'tool_calls': [{'name': 'add_to_shopping_cart', 'arguments': {'items': [{'product_id': 'B0BBFNHMYX', 'quantity': 1}], 'user_id': 'erewertyw', 'cart_id': 'ewyewyerwy'}}], 'available_tools': [{'name': 'add_to_shopping_cart', 'description': 'Add a list of provided items to the shopping cart.', 'parameters': {'type': 'object', 'properties': {'items': {'type': 'array', 'description': 'A list of items to add to the shopping cart. Each item is a dictionary with the following keys: product_id, quantity.'}, 'user_id': {'type': 'string', 'description': 'The id of the user to add the items to the shopping cart.'}, 'cart_id': {'type': 'string', 'description': 'The id of the shopping cart to add the items to.'}}}, 'required': ['items', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': 'A list of the items added to the shopping cart.'}}, {'name': 'remove_from_cart', 'description': 'Remove an item completely from the shopping cart.', 'parameters': {'type': 'object', 'properties': {'product_id': {'type': 'string', 'description': 'Product ID to remove'}, 'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['product_id', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': "True if item was removed, False if item wasn't found"}}, {'name': 'get_shopping_cart', 'description': "Retrieve all items in a user's shopping cart.", 'parameters': {'type': 'object', 'properties': {'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['user_id', 'cart_id'], 'returns': {'type': 'array', 'description': 'List of dictionaries containing cart items'}}]}, 'answer': 'Adding aeac Wireless Earbuds to your cart.'}, 'interrupts': []}})
# ('debug', {'step': 8, 'timestamp': '2025-11-29T08:56:54.403291+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-a69c-6736-8008-c21b2a6e79ba'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-8697-6184-8007-1773735d213d'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super co ...
# ('debug', {'step': 9, 'timestamp': '2025-11-29T08:56:54.403297+00:00', 'type': 'task', 'payload': {'id': '7123c9ce-d1c8-3a8f-5db3-6b1d884228de', 'name': 'shopping_cart_agent_tool_node', 'input': State(messages=[{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super comfortable the ergonomic in-ear design can maintain a firm fit every time, ensuring proper fit and extra comfort. High-fidelity sound quality-earbud headphones provide clear top-level sound quality in ...
# ('updates', {'shopping_cart_agent_tool_node': {'messages': [ToolMessage(content="Added [{'product_id': 'B0BBFNHMYX', 'quantity': 1}] to the shopping cart.", name='add_to_shopping_cart', tool_call_id='call_0')]}})
# ('debug', {'step': 9, 'timestamp': '2025-11-29T08:56:54.550999+00:00', 'type': 'task_result', 'payload': {'id': '7123c9ce-d1c8-3a8f-5db3-6b1d884228de', 'name': 'shopping_cart_agent_tool_node', 'error': None, 'result': {'messages': [ToolMessage(content="Added [{'product_id': 'B0BBFNHMYX', 'quantity': 1}] to the shopping cart.", name='add_to_shopping_cart', tool_call_id='call_0')]}, 'interrupts': []}})
# ('debug', {'step': 9, 'timestamp': '2025-11-29T08:56:54.551198+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-a806-648c-8009-7c785a0f2697'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-a69c-6736-8008-c21b2a6e79ba'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super co ...
# ('debug', {'step': 10, 'timestamp': '2025-11-29T08:56:54.551204+00:00', 'type': 'task', 'payload': {'id': 'b60eae40-1190-87b5-ed00-0d14531dc9e3', 'name': 'shopping_cart_agent', 'input': State(messages=[{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super comfortable the ergonomic in-ear design can maintain a firm fit every time, ensuring proper fit and extra comfort. High-fidelity sound quality-earbud headphones provide clear top-level sound quality in the reco ...
# ('updates', {'shopping_cart_agent': {'messages': [AIMessage(content='The aeac Wireless Earbuds have been added to your shopping cart.', additional_kwargs={}, response_metadata={})], 'shopping_cart_agent': {'iteration': 2, 'final_answer': True, 'tool_calls': [], 'available_tools': [{'name': 'add_to_shopping_cart', 'description': 'Add a list of provided items to the shopping cart.', 'parameters': {'type': 'object', 'properties': {'items': {'type': 'array', 'description': 'A list of items to add to the shopping cart. Each item is a dictionary with the following keys: product_id, quantity.'}, 'user_id': {'type': 'string', 'description': 'The id of the user to add the items to the shopping cart.'}, 'cart_id': {'type': 'string', 'description': 'The id of the shopping cart to add the items to.'}}}, 'required': ['items', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': 'A list of the items added to the shopping cart.'}}, {'name': 'remove_from_cart', 'description': 'Remove an item completely from the shopping cart.', 'parameters': {'type': 'object', 'properties': {'product_id': {'type': 'string', 'description': 'Product ID to remove'}, 'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['product_id', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': "True if item was removed, False if item wasn't found"}}, {'name': 'get_shopping_cart', 'description': "Retrieve all items in a user's shopping cart.", 'parameters': {'type': 'object', 'properties': {'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['user_id', 'cart_id'], 'returns': {'type': 'array', 'description': 'List of dictionaries containing cart items'}}]}, 'answer': 'The aeac Wireless Earbuds have been added to your shopping cart.'}})
# ('debug', {'step': 10, 'timestamp': '2025-11-29T08:56:55.713344+00:00', 'type': 'task_result', 'payload': {'id': 'b60eae40-1190-87b5-ed00-0d14531dc9e3', 'name': 'shopping_cart_agent', 'error': None, 'result': {'messages': [AIMessage(content='The aeac Wireless Earbuds have been added to your shopping cart.', additional_kwargs={}, response_metadata={})], 'shopping_cart_agent': {'iteration': 2, 'final_answer': True, 'tool_calls': [], 'available_tools': [{'name': 'add_to_shopping_cart', 'description': 'Add a list of provided items to the shopping cart.', 'parameters': {'type': 'object', 'properties': {'items': {'type': 'array', 'description': 'A list of items to add to the shopping cart. Each item is a dictionary with the following keys: product_id, quantity.'}, 'user_id': {'type': 'string', 'description': 'The id of the user to add the items to the shopping cart.'}, 'cart_id': {'type': 'string', 'description': 'The id of the shopping cart to add the items to.'}}}, 'required': ['items', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': 'A list of the items added to the shopping cart.'}}, {'name': 'remove_from_cart', 'description': 'Remove an item completely from the shopping cart.', 'parameters': {'type': 'object', 'properties': {'product_id': {'type': 'string', 'description': 'Product ID to remove'}, 'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['product_id', 'user_id', 'cart_id'], 'returns': {'type': 'string', 'description': "True if item was removed, False if item wasn't found"}}, {'name': 'get_shopping_cart', 'description': "Retrieve all items in a user's shopping cart.", 'parameters': {'type': 'object', 'properties': {'user_id': {'type': 'string', 'description': 'User ID'}, 'cart_id': {'type': 'string', 'description': 'Cart identifier'}}}, 'required': ['user_id', 'cart_id'], 'returns': {'type': 'array', 'description': 'List of dictionaries containing cart items'}}]}, 'answer': 'The aeac Wireless Earbuds have been added to your shopping cart.'}, 'interrupts': []}})
# ('debug', {'step': 10, 'timestamp': '2025-11-29T08:56:55.713457+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-b31c-609c-800a-f9e3a1941239'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test00001006', 'checkpoint_id': '1f0cd015-a806-648c-8009-7c785a0f2697'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?'}, AIMessage(content='I will find some earphones and laptops for you and provide positive and negative reviews for each suggestion.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}]), ToolMessage(content="- ID: B0BBFNHMYX, rating: 4.0, description: aeac Wireless Earbuds,Earbuds Wireless Bluetooth for iPhone，IPX5 Waterproof in-Ear Built-in Mic Headset,White\n- ID: B0BVPT6QJ4, rating: 4.6, description: Cleaner Kit for Airpods Pro 1 2 3 Multi-Function Cleaning Pen, 3 in 1 Multifunctional Cleaning Pen for Wireless Earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera (Black)Multifunctional Cleaning Pen: a good helper for Bluetooth earphone headset Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera cleaning, very easy to clean, safe and efficient, is your trusted brand. Hidden Dual Head Design: 3 in 1 Multifunctional Cleaning Pen with flocking sponge, high-density brush and metal pen tip, double-head hidden design, diverse use occasions, to meet the needs of different people. Easy to operate: the built-in cotton swab can be used to clean the earphone charging compartment, the other button is used to press and slide up, the brush at the other end can be used to bounce surface debris, and the pen tip can be used to clean debris from the speaker net. Built-in high-density brush: it can effectively clean up the debris of Wireless earphone, Bluetooth Headphone, Earphone Case, Keyboard, Camera, and has a long service life and is not easy to break. Metal sharp teeth: The Airpod cleaning pen has metal sharp teeth, which can powerfully clean debris and make your electronic products look brand new. Please note that in order to avoid damaging objects or bending in the process of using, please do not use too much force.\n- ID: B09PYK37K4, rating: 4.2, description: 100SEASHELL Long Cord Wired Earbuds no Microphone Headphones Watching tv with Extra Noise isolating Blocking bass Ear Buds Without mic Corded Length Earphones【Sound quality】 The sound quality is excellent, with full sound and enhanced bass. 【Purpose】This 3.5mm stereo headset is compatible with all of your devices, including your TV, mobile phone, laptop, computer, and tablet. 【Features】These long-wire earbuds are perfect for working out, watching TV, officeor, just sitting around. 【Comfortable】The earphone's ergonomic metal shell is designed to fit comfortably in your ear, and the wire clip and ear caps of different sizes are designed to fit different ear sizes. The earphone also has a magnetic function to help you store it. 【Version】 Version-there are microphones with and without a microphone, choose according to your needs.\n- ID: B09Y5DZW52, rating: 4.2, description: 6 Pack Earbuds Headphone Wired with Microphone,Noise Isolating in-Ear Bass Earbuds 3.5mm Stereo Earphones Interface Compatible with iPhone/Android Phones/PC Computers/MP3 Players/LaptopEarplugs with built-in microphones-built-in multi-function buttons and volume adjustment buttons make it more convenient for the headset to answer and control the volume. The solid sound insulation material design can reduce external noise while minimizing the sound leakage, providing you with a clear sound. Super c ...
